# %%
import sys
sys.path.append('../../..')

import numpy as np

from olfactory_navigation.environment import Environment
from olfactory_navigation.agents import FSVI_Agent
from olfactory_navigation.agents.model_based_util.pomdp import Model
from olfactory_navigation.simulation import run_test
from olfactory_navigation.test_setups import run_all_starts_test

from matplotlib import pyplot as plt
from matplotlib import colors, patches
from scipy.stats import multivariate_normal
from sklearn.metrics import confusion_matrix

# %%
from cupy.cuda import runtime as cuda_runtime
cuda_runtime.setDevice(1)

# %% [markdown]
# ## Variables

# %%
space_shape = np.array([101,101])
cells = np.array([9,9])
space_center = (space_shape / 2).astype(int)

source_radius = 2
source_cell_resolution = np.array([7,7])

data_mean = [50,50]
data_covariance = 50

# %% [markdown]
# ## Model

# %%
def generate_model(
        space_shape : np.ndarray,
        cells: np.ndarray,
        source_radius: int,
        source_cell_resolution: np.ndarray,
        data_mean: list,
        data_covariance: int
        ) -> Model:
    space_center = (space_shape / 2).astype(int)

    # Building probability map
    indices = np.arange(space_shape[0])
    x,y = np.meshgrid(indices, indices)
    pos = np.dstack((x, y))
    rv = multivariate_normal(data_mean, data_covariance)
    probability_map = rv.pdf(pos)

    # Normalize to have 1 at the center
    probability_map /= np.max(probability_map)

    # Building a grid-cell-mapping
    def build_grid_mapping(space_shape: np.ndarray = np.array([101,101]),
                       cells: np.ndarray = np.array([3,3]),
                       source_position: np.ndarray = np.array([50,50]),
                       source_radius: int = 4,
                       source_cell_resolution: np.ndarray = np.array([3,3])
                       ) -> np.ndarray:
        # Finding the sizes of the cells
        cell_size_standard = (space_shape / cells).astype(int)
        cell_size_overflow = (space_shape % cells).astype(int)

        # Determining cell sizes
        cell_sizes = []
        for ax_cells, ax_size, ax_overflow in zip(cells, cell_size_standard, cell_size_overflow):
            sizes = np.repeat(ax_size, ax_cells)
            if ax_overflow > 0:
                sizes[:int(np.floor(ax_overflow/2))] += 1
                sizes[-int(np.ceil(ax_overflow/2)):] += 1
            cell_sizes.append(sizes)

        # Finding the edges of the cells and filling a grid with ids
        cell_edges = [np.concatenate(([0], np.cumsum(ax_sizes))) for ax_sizes in cell_sizes]

        lower_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[:-1] for bounds_arr in cell_edges], indexing='ij')]).T
        upper_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[1 :] for bounds_arr in cell_edges], indexing='ij')]).T

        grid_cells = np.full(space_shape, -1)
        for i, (lower_b, upper_b) in enumerate(zip(lower_bounds, upper_bounds)):
            slices = [slice(ax_lower, ax_upper) for ax_lower, ax_upper in zip(lower_b, upper_b)]

            # Grid to cell mapping
            grid_cells[*slices] = i

        # Finding cell the replace
        source_cell_id = grid_cells[*source_position]
        source_cell = np.array(np.unravel_index(source_cell_id, cells))

        # Finding center and replacing with closest side
        source_cell_shape = np.array([sizes[int(ax_id)] for sizes, ax_id in zip(cell_sizes, source_cell)])

        # Splitting the center cell grid into subcells
        sub_cell_size_standard = (source_cell_shape / source_cell_resolution).astype(int)
        sub_cell_size_overflow = (source_cell_shape % source_cell_resolution).astype(int)

        sub_cell_sizes = []
        for ax_cells, ax_size, ax_overflow in zip(source_cell_resolution, sub_cell_size_standard, sub_cell_size_overflow):
            sizes = np.repeat(ax_size, ax_cells)
            if ax_overflow > 0:
                sizes[:int(np.floor(ax_overflow/2))] += 1
                sizes[-int(np.ceil(ax_overflow/2)):] += 1
            sub_cell_sizes.append(sizes)

        # Finding the edges of the cells and filling a grid with ids
        sub_cell_edges = [np.concatenate(([0], np.cumsum(ax_sizes))) for ax_sizes in sub_cell_sizes]

        sub_cell_lower_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[:-1] for bounds_arr in sub_cell_edges], indexing='ij')]).T
        sub_cell_upper_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[1 :] for bounds_arr in sub_cell_edges], indexing='ij')]).T

        sub_grid_cells = np.full(source_cell_shape, -1)
        for i, (lower_b, upper_b) in enumerate(zip(sub_cell_lower_bounds, sub_cell_upper_bounds)):
            slices = [slice(ax_lower, ax_upper) for ax_lower, ax_upper in zip(lower_b, upper_b)]

            # Grid to cell mapping
            sub_grid_cells[*slices] = i + np.prod(cells)

        # Injecting the sub_grid in the grid
        grid_cells[*[slice(lower_b, upper_b) for lower_b, upper_b in zip(lower_bounds[source_cell_id], upper_bounds[source_cell_id])]] = sub_grid_cells

        # Spacial indices
        spacial_indices = list(np.ndindex(tuple(space_shape)))
        spacial_indices_array = np.array(spacial_indices).astype(int)

        # Indices are at source
        at_source = np.sum((source_position[None,:] - spacial_indices_array) ** 2, axis=1) <= source_radius ** 2
        grid_cells[*spacial_indices_array[at_source].T] = -1

        return grid_cells

    # Generating state labels
    # Get the list of all indices
    indices_list = list(np.ndindex((*cells, *cells)))

    cell_indices = list(np.ndindex((*cells,)))
    source_cell_indices = list(np.ndindex((*source_cell_resolution,)))

    state_labels = []
    for (s_y, s_x) in cell_indices:
        for (a_y, a_x) in cell_indices:
            state_labels.append(f's_{s_y}_{s_x}-a_{a_y}_{a_x}')
        state_labels += [f's_{s_y}_{s_x}-sr_{source_y}_{source_x}' for (source_y, source_x) in source_cell_indices]
    state_labels.append('goal')

    # Generating action labels
    action_set = np.array([
        [-1,  0], # North
        [ 0,  1], # East
        [ 1,  0], # South
        [ 0, -1]  # West
    ])
    action_labels = [
        'North',
        'East',
        'South',
        'West'
    ]

    # Finding cell centers
    def find_sub_cell_centers(space_shape: np.ndarray = np.array([101,101]),
                            cells: np.ndarray = np.array([3,3]),
                            source_cell_resolution: np.ndarray = np.array([3,3])):
        # Finding the sizes of the cells
        cell_size_standard = (space_shape / cells).astype(int)
        cell_size_overflow = (space_shape % cells).astype(int)

        # Determining cell sizes
        cell_sizes = []
        for ax_cells, ax_size, ax_overflow in zip(cells, cell_size_standard, cell_size_overflow):
            sizes = np.repeat(ax_size, ax_cells)
            if ax_overflow > 0:
                sizes[:int(np.floor(ax_overflow/2))] += 1
                sizes[-int(np.ceil(ax_overflow/2)):] += 1
            cell_sizes.append(sizes)

        # Finding the edges of the cells and filling a grid with ids
        cell_edges = [np.concatenate(([0], np.cumsum(ax_sizes))) for ax_sizes in cell_sizes]

        lower_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[:-1] for bounds_arr in cell_edges], indexing='ij')]).T
        upper_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[1:] for bounds_arr in cell_edges], indexing='ij')]).T

        sub_cell_centers = []
        for tile_lower, tile_upper in zip(lower_bounds, upper_bounds):
            tile_shape = tile_upper - tile_lower

            sub_cell_size_standard = (tile_shape / source_cell_resolution).astype(int)
            sub_cell_size_overflow = (tile_shape % source_cell_resolution).astype(int)

            # Determining cell sizes
            sub_cell_sizes = []
            for ax_sub_cells, ax_sub_size, ax_sub_overflow in zip(source_cell_resolution, sub_cell_size_standard, sub_cell_size_overflow):
                sub_sizes = np.repeat(ax_sub_size, ax_sub_cells)
                if ax_sub_overflow > 0:
                    sub_sizes[:int(np.floor(ax_sub_overflow/2))] += 1
                    sub_sizes[-int(np.ceil(ax_sub_overflow/2)):] += 1
                sub_cell_sizes.append(sub_sizes)

            # Finding the edges of the cells and filling a grid with ids
            sub_cell_edges = [np.concatenate(([0], np.cumsum(ax_sub_sizes))) for ax_sub_sizes in sub_cell_sizes]

            sub_lower_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[:-1] for bounds_arr in sub_cell_edges], indexing='ij')]).T

            sub_centers = tile_lower + sub_lower_bounds + np.floor(sub_cell_size_standard / 2).astype(int)
            sub_cell_centers.append(sub_centers)

        centers = np.vstack(sub_cell_centers)
        return centers

    # Building transition probabilities
    source_positions = find_sub_cell_centers(space_shape=space_shape,
                                            cells=cells,
                                            source_cell_resolution=source_cell_resolution)

    # Spacial indices
    spacial_indices = list(np.ndindex(tuple(space_shape)))
    spacial_indices_array = np.array(spacial_indices).astype(int)

    # Set the transition probability matrix
    cell_count = np.prod(cells) + np.prod(source_cell_resolution) # ! Plus the sub cells zones of the source cell
    state_count = len(state_labels)
    action_count = len(action_set)
    transition_probabilities = np.zeros((state_count, action_count, state_count))

    for source_i, source_pos in enumerate(source_positions):
        macro_i = int(source_i / np.prod(source_cell_resolution))
        sub_grid_i = int(source_i % np.prod(source_cell_resolution))

        grid_cells = build_grid_mapping(space_shape=space_shape,
                                        cells=cells,
                                        source_position=source_pos,
                                        source_radius=source_radius,
                                        source_cell_resolution=source_cell_resolution)
        cells_from_indices = grid_cells[*spacial_indices_array.T]

        move_probabilities = []
        for move in action_set:
            # Applying the moves to the indices
            moved_indices = spacial_indices_array + move
            moved_indices_clipped = np.clip(moved_indices, 0, space_shape-1)

            # Converting moved indices to cell indices
            cells_from_indices_after_move = grid_cells[*moved_indices_clipped.T]

            # Building a confusion matrix of the moves
            conf = confusion_matrix(cells_from_indices, cells_from_indices_after_move, labels=[-1] + list(np.arange(cell_count)), normalize='true')
            move_probabilities.append(conf[:,None,:])

        # Stack probabilities
        move_probabilities = np.hstack(move_probabilities)

        # In case a cell is not used, make the transition loop on itself
        zero_move_probabilities = np.argwhere(move_probabilities.sum(axis=-1) == 0).T
        move_probabilities[zero_move_probabilities[0], zero_move_probabilities[1], zero_move_probabilities[0]] = 1.0

        # Set the values in the transition matrix
        macro_tile_start_state = (macro_i * cell_count)
        macro_tile_end_state = macro_tile_start_state + np.prod(cells)
        macro_tiles_slice = slice(macro_tile_start_state, macro_tile_end_state)

        sub_tile_start_state = macro_tile_end_state
        sub_tile_end_state = sub_tile_start_state + np.prod(source_cell_resolution)
        sub_tiles_slice = slice(sub_tile_start_state, sub_tile_end_state)

        macro_slice_move_probs = slice(1, (np.prod(cells)+1))
        sub_tile_slice_move_probs = slice((np.prod(cells)+1), (np.prod(cells)+np.prod(source_cell_resolution)+1))

        transition_probabilities[macro_tiles_slice, :, macro_tiles_slice] += move_probabilities[macro_slice_move_probs, :, macro_slice_move_probs] / np.prod(source_cell_resolution) # macro to macro
        transition_probabilities[macro_tiles_slice, :, sub_tiles_slice] += move_probabilities[macro_slice_move_probs, :, sub_tile_slice_move_probs] / np.prod(source_cell_resolution) # macro to sub
        transition_probabilities[sub_tiles_slice, :, macro_tiles_slice] += move_probabilities[sub_tile_slice_move_probs, :, macro_slice_move_probs] / np.prod(source_cell_resolution) # sub to macro
        transition_probabilities[sub_tiles_slice, :, sub_tiles_slice] += move_probabilities[sub_tile_slice_move_probs, :, sub_tile_slice_move_probs] / np.prod(source_cell_resolution) # sub to sub

        transition_probabilities[macro_tiles_slice, :, -1] += move_probabilities[macro_slice_move_probs, :, 0] / np.prod(source_cell_resolution) # macro to goal
        transition_probabilities[sub_tiles_slice, :, -1] += move_probabilities[sub_tile_slice_move_probs, :, 0] / np.prod(source_cell_resolution) # sub to goal
        transition_probabilities[-1, :, -1] = 1.0 # goal to goal

    assert np.all(transition_probabilities.sum(axis=-1).round(8) == 1.0)

    # Observations
    threshold = 3e-6

    # Compute observation matrix
    if not isinstance(threshold, list):
        threshold = [threshold]

    # Ensure 0.0 and 1.0 begin and end the threshold list
    if threshold[0] != -np.inf:
        threshold = [-np.inf] + threshold

    if threshold[-1] != np.inf:
        threshold = threshold + [np.inf]

    #  Observation labels
    observation_labels = ['nothing']
    if len(threshold) > 3:
        for i,_ in enumerate(threshold[1:-1]):
            observation_labels.append(f'something_l{i}')
    else:
        observation_labels.append('something')

    # Adding the agent position to the oservation labels
    agent_state_labels = [label.split('-')[1] for label in state_labels[:np.prod(cells)]]
    all_observation_labels = []
    for obs in observation_labels:
        for agent_state in agent_state_labels:
            all_observation_labels.append(f'{agent_state}-{obs}')

    observation_labels = all_observation_labels

    # Add goal
    observation_labels.append('goal')

    # Observation probabilities
    # Finding the sizes of the cells
    cell_size_standard = (space_shape / cells).astype(int)
    cell_size_overflow = (space_shape % cells).astype(int)

    # Determining cell sizes
    cell_sizes = []
    for ax_cells, ax_size, ax_overflow in zip(cells, cell_size_standard, cell_size_overflow):
        sizes = np.repeat(ax_size, ax_cells)
        if ax_overflow > 0:
            sizes[:int(np.floor(ax_overflow/2))] += 1
            sizes[-int(np.ceil(ax_overflow/2)):] += 1
        cell_sizes.append(sizes)

    # Finding the edges of the cells and filling a grid with ids
    cell_edges = [np.concatenate(([0], np.cumsum(ax_sizes))) for ax_sizes in cell_sizes]

    lower_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[:-1] for bounds_arr in cell_edges], indexing='ij')]).T
    upper_bounds = np.array([ax_arr.ravel() for ax_arr in np.meshgrid(*[bounds_arr[1 :] for bounds_arr in cell_edges], indexing='ij')]).T


    cell_probabilities = np.full(cells, -1, dtype=float)
    for cell, lower_b, upper_b in zip(list(np.ndindex(tuple(cells))), lower_bounds, upper_bounds):
        slices = [slice(ax_lower, ax_upper) for ax_lower, ax_upper in zip(lower_b, upper_b)]

        # TODO: Make it flexible to multi thresh
        cell_probabilities[*cell] = np.average(probability_map[*slices])

    indices_array = np.array(indices_list)
    relative_indices = indices_array[:,:len(cells)] - indices_array[:,len(cells):]

    # Shifting the relative positions by the position of the center
    center_pos = (cells / 2).astype(int)
    centered_positions = relative_indices + center_pos

    # Filtering to the valid centered positions
    valid_positions = np.all((centered_positions >= 0) & (centered_positions < cells), axis=1)
    filtered_centered_positions = centered_positions[valid_positions]
    filtered_indices_array = indices_array[valid_positions]

    # Gathering the cell_probabilities
    odor_probabilities = np.zeros((*cells, *cells), dtype=float)
    odor_probabilities[*filtered_indices_array.T] = cell_probabilities[*filtered_centered_positions.T]

    # Generating an empty observation matrix
    observations = np.zeros((len(state_labels), len(action_set), len(observation_labels)))

    # Filling the something/nothing observations
    agent_cells = indices_array[:np.prod(cells),2:]
    for obs_i, agent_cell in enumerate(agent_cells):
        # For observation matrix
        agent_ids_in_states = (np.arange(np.prod(cells)) * cell_count) + obs_i

        # To read odor probability matrix
        agent_ids_in_space = np.all(indices_array[:,2:] == agent_cell, axis=1)
        filtered_agent_ids_in_space = indices_array[agent_ids_in_space]

        # Setting the probabilities in the matrix
        probabilities_at_agent_position = odor_probabilities[*filtered_agent_ids_in_space.T][:,None]
        observations[agent_ids_in_states,:,obs_i] = 1 - probabilities_at_agent_position # Nothing
        observations[agent_ids_in_states,:,obs_i+len(agent_cells)] = probabilities_at_agent_position # Something

        # Finding sub-cells of the source cell
        sub_cell_source_ids = ((obs_i * cell_count) + np.prod(cells)) + np.arange(np.prod(source_cell_resolution))
        observations[sub_cell_source_ids,:,obs_i] = 1 - probabilities_at_agent_position[obs_i] # Nothing
        observations[sub_cell_source_ids,:,obs_i+len(agent_cells)] = probabilities_at_agent_position[obs_i] # Something

        # Finding the cells  where the agent is at the source
        agent_at_source_id = (obs_i * cell_count) + obs_i
        observations[agent_at_source_id,:,obs_i] = 1.0 # Nothing
        observations[agent_at_source_id,:,obs_i+len(agent_cells)] = 0.0 # Something


    # Goal observations
    observations[-1,:,0] = 0.0
    observations[:,:,-1] = 0.0
    observations[-1,:,-1] = 1.0 # Goal

    assert np.all(observations.sum(axis=-1).round(8) == 1.0)

    # Building model
    model = Model(
        states = state_labels,
        actions = action_labels,
        observations = observation_labels,
        transitions = transition_probabilities,
        observation_table = observations,
        end_states = [len(state_labels)-1], # The very last state is the goal state
        # start_probabilities = start_probabilities,
        seed=12131415
    )

    return model

# %%
model = generate_model(
    space_shape=space_shape,
    cells=cells,
    source_radius=source_radius,
    source_cell_resolution=source_cell_resolution,
    data_mean=data_mean,
    data_covariance=data_covariance
)

# %% [markdown]
# ## Agent

# %%
def generate_fake_data(
        space_shape: np.ndarray,
        data_mean: list,
        data_covariance,
        samples: int
        ) -> np.ndarray:
    x,y = np.meshgrid(np.arange(space_shape[0]), np.arange(space_shape[1]))
    pos = np.dstack((x, y))
    rv = multivariate_normal(data_mean, data_covariance)
    probability_map = rv.pdf(pos)

    # Normalize to have 1 at the center
    probability_map /= np.max(probability_map)

    multiple_samples = (np.random.random((samples, *space_shape)) < probability_map).astype(float)

    return multiple_samples

# %%
artificial_data = generate_fake_data(space_shape=space_shape,
                                     data_mean=data_mean,
                                     data_covariance=data_covariance,
                                     samples=1000)

artificial_env  = Environment(data_file=artificial_data,
                              data_source_position=space_center,
                              source_radius=source_radius,
                              shape=space_shape,
                              boundary_condition='stop',
                              start_zone='data_zone',
                              odor_present_threshold=3e-1)

artificial_env.plot()

# %%
ag = FSVI_Agent(environment=artificial_env,
                threshold=3e-8,
                space_aware=True,
                spacial_subdivisions=cells,
                model=model)

# %%
_ = ag.train(expansions=300, use_gpu=True)
# Out:
# [11/27/2024, 13:52:30] MDP_policy, not provided. Solving MDP with Value Iteration...
# [11/27/2024, 13:52:30] Sending Model to GPU...
# [11/27/2024, 13:52:33]     > Done in 2.787s
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Summary of Value Iteration run
#   - Model: 10531-state, 4-action
#   - Converged in 918 iterations and 3.7242 seconds
#   - Took on average 0.0041s per iteration
# Expansions:   0%|          | 0/300 [00:00<?, ?it/s]
# Memory full: Out of memory allocating 36,802,896,384 bytes (allocated so far: 47,646,379,520 bytes).
# Returning value function and history as is...
#
# Summary of Point Based Value Iteration run
#   - Model: 10531 state, 4 action, 163 observations
#   - Converged or stopped after 120 expansion steps and 119 backup steps.
#   - Resulting value function has 670 alpha vectors.
#   - Converged in 207.2881s
#
#   - Expand function took on average 0.0162s and yielded on average 483.61 beliefs per iteration. (0.0002s/it/belief)
#   - Backup function took on average 1.7255s and yielded on average 5.60 alpha vectors per iteration. (0.0051s/it/alpha)
#   - Pruning function took on average 0.0000s and yielded on average prunings of 0.00 alpha vectors per iteration.

# %%
# CUSTOM PLOT
COLOR_LIST = [{
    'name': item.replace('tab:',''),
    'id': item,
    'hex': value,
    'rgb': [int(value.lstrip('#')[i:i + (len(value)-1) // 3], 16) for i in range(0, (len(value)-1), (len(value)-1) // 3)]
    } for item, value in colors.TABLEAU_COLORS.items()] # type: ignore

COLOR_ARRAY = np.array([c['rgb'] for c in COLOR_LIST])

# VF
vf = ag.value_function
new_shape = cells

# ! Select here which source to plot
source_policy = [0,0]
source_policy_id = np.arange(np.prod(cells)).reshape(cells)[*source_policy]
source_state_start = source_policy_id * np.prod(cells)

value_table = np.max(vf.alpha_vector_array, axis=0)[vf.model.state_grid[:,source_state_start:source_state_start+np.prod(cells)]].reshape(new_shape)
best_action_table = np.array(vf.actions)[np.argmax(vf.alpha_vector_array, axis=0)][vf.model.state_grid[:,source_state_start:source_state_start+np.prod(cells)]].reshape(new_shape)
best_action_colors = COLOR_ARRAY[best_action_table]

dimensions = new_shape

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(5*2, 5), width_ratios=(0.55,0.45))

# Ticks
x_ticks = np.arange(0, dimensions[1], (1 if dimensions[1] < 10 else int(dimensions[1] / 10)))
y_ticks = np.arange(0, dimensions[0], (1 if dimensions[0] < 5 else int(dimensions[0] / 5)))

ax1.set_title('Value function')
ax1_plot = ax1.imshow(value_table)

if dimensions[0] >= dimensions[1]: # If higher than wide
    plt.colorbar(ax1_plot, ax=ax1)
else:
    plt.colorbar(ax1_plot, ax=ax1, location='bottom', orientation='horizontal')

ax1.set_xticks(x_ticks)
ax1.set_yticks(y_ticks)

ax2.set_title('Action policy')
ax2.imshow(best_action_colors)
p = [ patches.Patch(color=COLOR_LIST[int(i)]['id'], label=str(vf.model.action_labels[int(i)])) for i in vf.model.actions]
ax2.legend(handles=p, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title='Actions')
ax2.set_xticks(x_ticks)
ax2.set_yticks(y_ticks)

plt.show()

# %% [markdown]
# ### Validation on the artificial data

# %%
hist = run_all_starts_test(ag,
                           horizon=1000,
                           use_gpu=True)
# Out:
# Using the provided environment, not the agent environment.
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Simulations done in 46.992s:
# Simulations reached goal: 10186/10188 (2 failures (reached horizon: 2)) (99.98% success)
#  - Average step count:                 192.141 +- 119.41 (Successful only: 191.982 +- 118.89)
#  - Extra steps:                        143.583 +- 117.47 (Successful only: 143.427 +- 116.96)
#  - Average discounted rewards (ADR):   0.229 +- 0.18 (Successful only: 0.229 +- 0.18)
#  - Tmin/T:                             0.333 +- 0.21 (Successful only: 0.333 +- 0.21)

# %%
_, ax = plt.subplots(1,1, figsize=(10,10))
hist.plot_successes(ax)

# %%
_, ax = plt.subplots(figsize=(10,10))
hist.plot(7000, ax= ax)

# %% [markdown]
# ## Test

# %%
shift = np.array([-7,-7])

shifted_artificial_data = np.zeros(artificial_data.shape)
trimmed_artificial_data = artificial_data[:, *[slice(0, -s) if s >=0 else slice(-s, shape) for shape, s in zip(space_shape, shift)]]
shifted_artificial_data[:, *[slice(s, shape) if s >=0 else slice(0, s) for shape, s in zip(space_shape, shift)]] = trimmed_artificial_data

# %%
shifted_artificial_env  = Environment(data_file=shifted_artificial_data,
                                      data_source_position=(np.array([50,50]) + shift).tolist(),
                                      source_radius=source_radius,
                                      shape=space_shape,
                                      boundary_condition='stop',
                                      start_zone='data_zone',
                                      odor_present_threshold=3e-1)

shifted_artificial_env.plot()

# %%
hist = run_all_starts_test(ag,
                           environment=shifted_artificial_env,
                           horizon=1000,
                           use_gpu=True)
# Out:
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Simulations done in 190.822s:
# Simulations reached goal: 2156/10188 (8032 failures (reached horizon: 8032)) (21.16% success)
#  - Average step count:                 836.436 +- 328.27 (Successful only: 227.091 +- 195.65)
#  - Extra steps:                        786.907 +- 328.63 (Successful only: 177.759 +- 194.73)
#  - Average discounted rewards (ADR):   0.050 +- 0.13 (Successful only: 0.234 +- 0.21)
#  - Tmin/T:                             0.112 +- 0.16 (Successful only: 0.346 +- 0.24)

# %%
_, ax = plt.subplots(1,1, figsize=(10,10))
hist.plot_successes(ax)

# %%
_, ax = plt.subplots(1,1, figsize=(10,10))
hist.plot(2000, ax=ax)

# %%
hist.analysis_df
# Out:
#                                 y      x  optimal_steps_count converged  \
# mean                          NaN    NaN                  NaN  0.211622
# standard_deviation            NaN    NaN                  NaN  0.408458
# success_mean                  NaN    NaN                  NaN       1.0
# success_standard_deviation    NaN    NaN                  NaN       0.0
# run_0                         0.0    0.0                 84.0     False
# ...                           ...    ...                  ...       ...
# run_10183                   100.0   96.0                108.0     False
# run_10184                   100.0   97.0                109.0     False
# run_10185                   100.0   98.0                110.0      True
# run_10186                   100.0   99.0                111.0     False
# run_10187                   100.0  100.0                112.0     False
#
#                            reached_horizon  steps_taken  discounted_rewards  \
# mean                              0.788378   836.435807            0.049600
# standard_deviation                0.408458   328.274533            0.134702
# success_mean                           0.0   227.090909            0.234220
# success_standard_deviation             0.0   195.653337            0.206219
# run_0                                 True  1000.000000            0.000043
# ...                                    ...          ...                 ...
# run_10183                             True  1000.000000            0.000043
# run_10184                             True  1000.000000            0.000043
# run_10185                            False   862.000000            0.000173
# run_10186                             True  1000.000000            0.000043
# run_10187                             True  1000.000000            0.000043
#
#                             extra_steps  t_min_over_t
# mean                         786.906753      0.112366
# standard_deviation           328.629265      0.164611
# success_mean                 177.758813      0.346265
# success_standard_deviation   194.726919      0.238556
# run_0                        916.000000      0.084000
# ...                                 ...           ...
# run_10183                    892.000000      0.108000
# run_10184                    891.000000      0.109000
# run_10185                    752.000000      0.127610
# run_10186                    889.000000      0.111000
# run_10187                    888.000000      0.112000
#
# [10192 rows x 9 columns]

# %% [markdown]
# ## All Tests

# %%
# Complete test
all_hists = []
for i in range(1,50,2):
    shift = np.array([-i,-i])
    print(f'\n{shift = }')

    # Setup shifted environment
    shifted_artificial_data = np.zeros(artificial_data.shape)
    trimmed_artificial_data = artificial_data[:, *[slice(0, -s) if s > 0 else slice(-s, shape) for shape, s in zip(space_shape, shift)]]
    shifted_artificial_data[:, *[slice(s, shape) if s >=0 else slice(0, s) for shape, s in zip(space_shape, shift)]] = trimmed_artificial_data

    shifted_artificial_env  = Environment(data_file=shifted_artificial_data,
                                          data_source_position=(np.array([50,50]) + shift).tolist(),
                                          source_radius=source_radius,
                                          shape=space_shape,
                                          boundary_condition='stop',
                                          start_zone='data_zone',
                                          odor_present_threshold=3e-1)

    # Running test
    hist = run_all_starts_test(ag,
                               environment=shifted_artificial_env,
                               horizon=1000,
                               use_gpu=True,
                               print_progress=False)

    all_hists.append(hist)
# Out:
# shift = array([-1, -1])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 55.724s:
# Simulations reached goal: 10096/10188 (92 failures (reached horizon: 92)) (99.10% success)
#  - Average step count:                 233.559 +- 199.25 (Successful only: 226.575 +- 186.18)
#  - Extra steps:                        184.982 +- 198.20 (Successful only: 178.024 +- 185.15)
#  - Average discounted rewards (ADR):   0.214 +- 0.18 (Successful only: 0.216 +- 0.18)
#  - Tmin/T:                             0.316 +- 0.21 (Successful only: 0.318 +- 0.21)
#
# shift = array([-3, -3])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 85.433s:
# Simulations reached goal: 9456/10188 (732 failures (reached horizon: 732)) (92.82% success)
#  - Average step count:                 366.415 +- 263.43 (Successful only: 317.368 +- 203.20)
#  - Extra steps:                        317.679 +- 261.87 (Successful only: 268.695 +- 201.14)
#  - Average discounted rewards (ADR):   0.123 +- 0.16 (Successful only: 0.132 +- 0.16)
#  - Tmin/T:                             0.216 +- 0.18 (Successful only: 0.228 +- 0.18)
#
# shift = array([-5, -5])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 159.154s:
# Simulations reached goal: 7114/10188 (3074 failures (reached horizon: 3074)) (69.83% success)
#  - Average step count:                 694.789 +- 309.66 (Successful only: 562.906 +- 282.30)
#  - Extra steps:                        645.736 +- 308.97 (Successful only: 514.131 +- 281.33)
#  - Average discounted rewards (ADR):   0.046 +- 0.12 (Successful only: 0.066 +- 0.14)
#  - Tmin/T:                             0.117 +- 0.14 (Successful only: 0.146 +- 0.16)
#
# shift = array([-7, -7])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 190.846s:
# Simulations reached goal: 2156/10188 (8032 failures (reached horizon: 8032)) (21.16% success)
#  - Average step count:                 836.436 +- 328.27 (Successful only: 227.091 +- 195.65)
#  - Extra steps:                        786.907 +- 328.63 (Successful only: 177.759 +- 194.73)
#  - Average discounted rewards (ADR):   0.050 +- 0.13 (Successful only: 0.234 +- 0.21)
#  - Tmin/T:                             0.112 +- 0.16 (Successful only: 0.346 +- 0.24)
#
# shift = array([-9, -9])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 154.831s:
# Simulations reached goal: 4132/10188 (6056 failures (reached horizon: 6056)) (40.56% success)
#  - Average step count:                 675.669 +- 399.66 (Successful only: 200.318 +- 117.07)
#  - Extra steps:                        625.505 +- 399.36 (Successful only: 150.458 +- 113.44)
#  - Average discounted rewards (ADR):   0.086 +- 0.16 (Successful only: 0.213 +- 0.18)
#  - Tmin/T:                             0.159 +- 0.19 (Successful only: 0.319 +- 0.21)
#
# shift = array([-11, -11])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 53.304s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 222.523 +- 125.98 (Successful only: 222.523 +- 125.98)
#  - Extra steps:                        171.566 +- 121.64 (Successful only: 171.566 +- 121.65)
#  - Average discounted rewards (ADR):   0.184 +- 0.17 (Successful only: 0.184 +- 0.17)
#  - Tmin/T:                             0.289 +- 0.18 (Successful only: 0.289 +- 0.18)
#
# shift = array([-13, -13])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 71.992s:
# Simulations reached goal: 9821/10188 (367 failures (reached horizon: 367)) (96.40% success)
#  - Average step count:                 306.366 +- 225.71 (Successful only: 280.446 +- 184.94)
#  - Extra steps:                        254.458 +- 225.56 (Successful only: 228.234 +- 183.50)
#  - Average discounted rewards (ADR):   0.139 +- 0.16 (Successful only: 0.145 +- 0.16)
#  - Tmin/T:                             0.245 +- 0.17 (Successful only: 0.252 +- 0.17)
#
# shift = array([-15, -15])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 123.815s:
# Simulations reached goal: 8877/10188 (1311 failures (reached horizon: 1311)) (87.13% success)
#  - Average step count:                 536.926 +- 278.55 (Successful only: 468.537 +- 229.59)
#  - Extra steps:                        483.907 +- 276.99 (Successful only: 415.417 +- 226.95)
#  - Average discounted rewards (ADR):   0.053 +- 0.12 (Successful only: 0.061 +- 0.12)
#  - Tmin/T:                             0.143 +- 0.13 (Successful only: 0.157 +- 0.14)
#
# shift = array([-17, -17])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 193.826s:
# Simulations reached goal: 2420/10188 (7768 failures (reached horizon: 7768)) (23.75% success)
#  - Average step count:                 849.433 +- 303.87 (Successful only: 366.125 +- 287.07)
#  - Extra steps:                        795.145 +- 304.05 (Successful only: 312.962 +- 286.48)
#  - Average discounted rewards (ADR):   0.039 +- 0.12 (Successful only: 0.163 +- 0.20)
#  - Tmin/T:                             0.108 +- 0.15 (Successful only: 0.278 +- 0.24)
#
# shift = array([-19, -19])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 189.207s:
# Simulations reached goal: 2223/10188 (7965 failures (reached horizon: 7965)) (21.82% success)
#  - Average step count:                 827.993 +- 333.32 (Successful only: 211.693 +- 152.84)
#  - Extra steps:                        772.278 +- 334.19 (Successful only: 154.963 +- 147.53)
#  - Average discounted rewards (ADR):   0.051 +- 0.14 (Successful only: 0.235 +- 0.20)
#  - Tmin/T:                             0.125 +- 0.17 (Successful only: 0.373 +- 0.23)
#
# shift = array([-21, -21])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 70.108s:
# Simulations reached goal: 10052/10188 (136 failures (reached horizon: 136)) (98.67% success)
#  - Average step count:                 297.291 +- 210.89 (Successful only: 287.783 +- 195.73)
#  - Extra steps:                        239.989 +- 206.07 (Successful only: 230.436 +- 190.26)
#  - Average discounted rewards (ADR):   0.153 +- 0.18 (Successful only: 0.155 +- 0.18)
#  - Tmin/T:                             0.271 +- 0.19 (Successful only: 0.274 +- 0.19)
#
# shift = array([-23, -23])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 72.729s:
# Simulations reached goal: 10150/10188 (38 failures (reached horizon: 38)) (99.63% success)
#  - Average step count:                 308.745 +- 192.38 (Successful only: 306.157 +- 188.03)
#  - Extra steps:                        249.699 +- 185.20 (Successful only: 247.111 +- 180.65)
#  - Average discounted rewards (ADR):   0.135 +- 0.17 (Successful only: 0.135 +- 0.17)
#  - Tmin/T:                             0.253 +- 0.17 (Successful only: 0.254 +- 0.17)
#
# shift = array([-25, -25])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 109.821s:
# Simulations reached goal: 9100/10188 (1088 failures (reached horizon: 1088)) (89.32% success)
#  - Average step count:                 474.386 +- 273.64 (Successful only: 411.544 +- 216.47)
#  - Extra steps:                        413.437 +- 268.77 (Successful only: 351.618 +- 212.01)
#  - Average discounted rewards (ADR):   0.066 +- 0.13 (Successful only: 0.074 +- 0.14)
#  - Tmin/T:                             0.176 +- 0.14 (Successful only: 0.189 +- 0.14)
#
# shift = array([-27, -27])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 173.083s:
# Simulations reached goal: 6217/10188 (3971 failures (reached horizon: 3971)) (61.02% success)
#  - Average step count:                 756.179 +- 289.29 (Successful only: 600.443 +- 273.73)
#  - Extra steps:                        693.168 +- 287.07 (Successful only: 539.581 +- 271.80)
#  - Average discounted rewards (ADR):   0.030 +- 0.10 (Successful only: 0.049 +- 0.13)
#  - Tmin/T:                             0.116 +- 0.13 (Successful only: 0.148 +- 0.15)
#
# shift = array([-29, -29])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 188.424s:
# Simulations reached goal: 2421/10188 (7767 failures (reached horizon: 7767)) (23.76% success)
#  - Average step count:                 825.272 +- 329.71 (Successful only: 264.715 +- 212.90)
#  - Extra steps:                        760.040 +- 332.48 (Successful only: 195.440 +- 208.75)
#  - Average discounted rewards (ADR):   0.046 +- 0.13 (Successful only: 0.194 +- 0.20)
#  - Tmin/T:                             0.140 +- 0.18 (Successful only: 0.384 +- 0.24)
#
# shift = array([-31, -31])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 122.149s:
# Simulations reached goal: 6498/10188 (3690 failures (reached horizon: 3690)) (63.78% success)
#  - Average step count:                 529.118 +- 368.91 (Successful only: 261.720 +- 126.35)
#  - Extra steps:                        461.507 +- 374.80 (Successful only: 189.134 +- 121.58)
#  - Average discounted rewards (ADR):   0.090 +- 0.15 (Successful only: 0.141 +- 0.17)
#  - Tmin/T:                             0.236 +- 0.21 (Successful only: 0.337 +- 0.21)
#
# shift = array([-33, -33])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 67.205s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 284.270 +- 143.05 (Successful only: 284.270 +- 143.05)
#  - Extra steps:                        214.121 +- 136.96 (Successful only: 214.121 +- 136.97)
#  - Average discounted rewards (ADR):   0.133 +- 0.17 (Successful only: 0.133 +- 0.17)
#  - Tmin/T:                             0.303 +- 0.19 (Successful only: 0.303 +- 0.19)
#
# shift = array([-35, -35])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 98.506s:
# Simulations reached goal: 9949/10188 (239 failures (reached horizon: 239)) (97.65% success)
#  - Average step count:                 424.387 +- 231.34 (Successful only: 410.559 +- 216.00)
#  - Extra steps:                        351.541 +- 225.60 (Successful only: 337.724 +- 209.69)
#  - Average discounted rewards (ADR):   0.080 +- 0.15 (Successful only: 0.082 +- 0.15)
#  - Tmin/T:                             0.225 +- 0.17 (Successful only: 0.228 +- 0.17)
#
# shift = array([-37, -37])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 149.126s:
# Simulations reached goal: 8984/10188 (1204 failures (reached horizon: 1204)) (88.18% success)
#  - Average step count:                 650.755 +- 241.29 (Successful only: 603.951 +- 217.93)
#  - Extra steps:                        575.054 +- 235.03 (Successful only: 528.713 +- 210.52)
#  - Average discounted rewards (ADR):   0.022 +- 0.08 (Successful only: 0.025 +- 0.09)
#  - Tmin/T:                             0.135 +- 0.10 (Successful only: 0.143 +- 0.11)
#
# shift = array([-39, -39])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 154.520s:
# Simulations reached goal: 6619/10188 (3569 failures (reached horizon: 3569)) (64.97% success)
#  - Average step count:                 673.932 +- 310.06 (Successful only: 498.115 +- 244.43)
#  - Extra steps:                        595.218 +- 306.63 (Successful only: 422.396 +- 242.28)
#  - Average discounted rewards (ADR):   0.032 +- 0.09 (Successful only: 0.050 +- 0.11)
#  - Tmin/T:                             0.157 +- 0.13 (Successful only: 0.196 +- 0.15)
#
# shift = array([-41, -41])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 134.893s:
# Simulations reached goal: 7022/10188 (3166 failures (reached horizon: 3166)) (68.92% success)
#  - Average step count:                 586.386 +- 316.14 (Successful only: 399.901 +- 181.94)
#  - Extra steps:                        504.499 +- 317.64 (Successful only: 317.319 +- 181.18)
#  - Average discounted rewards (ADR):   0.044 +- 0.11 (Successful only: 0.064 +- 0.12)
#  - Tmin/T:                             0.197 +- 0.15 (Successful only: 0.250 +- 0.16)
#
# shift = array([-43, -43])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 106.199s:
# Simulations reached goal: 9694/10188 (494 failures (reached horizon: 494)) (95.15% success)
#  - Average step count:                 459.230 +- 205.94 (Successful only: 431.673 +- 170.04)
#  - Extra steps:                        374.012 +- 207.16 (Successful only: 345.239 +- 167.15)
#  - Average discounted rewards (ADR):   0.045 +- 0.11 (Successful only: 0.048 +- 0.11)
#  - Tmin/T:                             0.222 +- 0.14 (Successful only: 0.230 +- 0.14)
#
# shift = array([-45, -45])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 129.192s:
# Simulations reached goal: 9985/10188 (203 failures (reached horizon: 203)) (98.01% success)
#  - Average step count:                 562.159 +- 191.76 (Successful only: 553.257 +- 183.16)
#  - Extra steps:                        473.451 +- 189.69 (Successful only: 464.203 +- 179.93)
#  - Average discounted rewards (ADR):   0.022 +- 0.08 (Successful only: 0.022 +- 0.08)
#  - Tmin/T:                             0.175 +- 0.11 (Successful only: 0.177 +- 0.11)
#
# shift = array([-47, -47])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 181.820s:
# Simulations reached goal: 5654/10188 (4534 failures (reached horizon: 4534)) (55.50% success)
#  - Average step count:                 797.117 +- 227.57 (Successful only: 634.423 +- 183.97)
#  - Extra steps:                        704.761 +- 226.37 (Successful only: 543.348 +- 180.22)
#  - Average discounted rewards (ADR):   0.008 +- 0.05 (Successful only: 0.014 +- 0.07)
#  - Tmin/T:                             0.128 +- 0.08 (Successful only: 0.155 +- 0.09)
#
# shift = array([-49, -49])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 226.732s:
# Simulations reached goal: 12/10190 (10178 failures (reached horizon: 10178)) (0.12% success)
#  - Average step count:                 998.825 +- 34.22 (Successful only: 2.083 +- 1.00)
#  - Extra steps:                        902.681 +- 51.36 (Successful only: 0.250 +- 0.87)
#  - Average discounted rewards (ADR):   0.001 +- 0.03 (Successful only: 0.979 +- 0.01)
#  - Tmin/T:                             0.097 +- 0.05 (Successful only: 0.938 +- 0.22)

# %%
# Extracting performance metrics
convergences = []
convergences_std = []
tmin_over_ts = []
tmin_over_ts_std = []

for hist in all_hists:
    df = hist.analysis_df
    convergences.append(df['converged']['mean'])
    convergences_std.append(df['converged']['standard_deviation'])
    tmin_over_ts.append(df['t_min_over_t']['success_mean'])
    tmin_over_ts_std.append(df['t_min_over_t']['success_standard_deviation'])

# %%
_, (ax0) = plt.subplots(1,1, figsize=(10,5), gridspec_kw={'hspace':0.3})
xs = (np.arange(len(convergences)) * 2) + 1

# Convergence plot
ax0.set_title('Performances of the agent when shifting the source (convergence)')
ax0.errorbar(xs, convergences, convergences_std)

# Other formatting
ax0.grid()
ax0.set_xticks(xs)
ax0.set_yticks([0.0, 0.5, 1.0], labels=[0, 50, 100])
ax0.set_ylabel('Convergence (%)')
ax0.set_xlabel('Shift from center along diagonal')
# Out:
# Text(0.5, 0, 'Shift from center along diagonal')

# %%
_, (ax1) = plt.subplots(1,1, figsize=(10,5), gridspec_kw={'hspace':0.3})

# tmin over t plot
ax1.set_title('Performances of the agent when shifting the source ($t_{min}/t$)')
ax1.errorbar(xs, tmin_over_ts, tmin_over_ts_std)

# Other formatting
ax1.grid()
ax1.set_xticks(xs)
ax1.set_yticks(np.arange(6)/10)
ax1.set_ylabel('$t_{min}/t$')
ax1.set_xlabel('Shift from center along diagonal')
# Out:
# Text(0.5, 0, 'Shift from center along diagonal')

# %% [markdown]
# ## Grid check

# %%
point_array = np.array(list(np.ndindex(5,5))) * -2

print(f'{len(point_array) = }')
# Out:
# len(point_array) = 25

# %%
# Complete test
all_point_hists = []
for shift in point_array:
    print(f'\n{shift = }')

    # Setup shifted environment
    shifted_artificial_data = np.zeros(artificial_data.shape)
    trimmed_artificial_data = artificial_data[:, *[slice(0, -s) if s > 0 else slice(-s, shape) for shape, s in zip(space_shape, shift)]]
    shifted_artificial_data[:, *[slice(s, shape) if s >=0 else slice(0, s) for shape, s in zip(space_shape, shift)]] = trimmed_artificial_data

    shifted_artificial_env  = Environment(data_file=shifted_artificial_data,
                                          data_source_position=(np.array([50,50]) + shift).tolist(),
                                          source_radius=source_radius,
                                          shape=space_shape,
                                          boundary_condition='stop',
                                          start_zone='data_zone',
                                          odor_present_threshold=3e-1)

    # Running test
    hist = run_all_starts_test(ag,
                               environment=shifted_artificial_env,
                               horizon=1000,
                               use_gpu=True,
                               print_progress=False)

    all_point_hists.append(hist)
# Out:
# shift = array([0, 0])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 46.711s:
# Simulations reached goal: 10186/10188 (2 failures (reached horizon: 2)) (99.98% success)
#  - Average step count:                 192.141 +- 119.41 (Successful only: 191.982 +- 118.89)
#  - Extra steps:                        143.583 +- 117.47 (Successful only: 143.427 +- 116.96)
#  - Average discounted rewards (ADR):   0.229 +- 0.18 (Successful only: 0.229 +- 0.18)
#  - Tmin/T:                             0.333 +- 0.21 (Successful only: 0.333 +- 0.21)
#
# shift = array([ 0, -2])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 57.278s:
# Simulations reached goal: 10005/10188 (183 failures (reached horizon: 183)) (98.20% success)
#  - Average step count:                 240.505 +- 198.92 (Successful only: 226.613 +- 171.91)
#  - Extra steps:                        191.908 +- 199.13 (Successful only: 177.905 +- 171.62)
#  - Average discounted rewards (ADR):   0.201 +- 0.18 (Successful only: 0.204 +- 0.17)
#  - Tmin/T:                             0.304 +- 0.21 (Successful only: 0.309 +- 0.21)
#
# shift = array([ 0, -4])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 83.462s:
# Simulations reached goal: 9086/10188 (1102 failures (reached horizon: 1102)) (89.18% success)
#  - Average step count:                 358.124 +- 291.57 (Successful only: 280.274 +- 198.23)
#  - Extra steps:                        309.408 +- 291.75 (Successful only: 231.260 +- 197.33)
#  - Average discounted rewards (ADR):   0.147 +- 0.17 (Successful only: 0.164 +- 0.18)
#  - Tmin/T:                             0.246 +- 0.21 (Successful only: 0.270 +- 0.21)
#
# shift = array([ 0, -6])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 160.360s:
# Simulations reached goal: 5553/10188 (4635 failures (reached horizon: 4635)) (54.51% success)
#  - Average step count:                 700.324 +- 362.85 (Successful only: 450.190 +- 322.57)
#  - Extra steps:                        651.410 +- 361.20 (Successful only: 402.120 +- 320.01)
#  - Average discounted rewards (ADR):   0.079 +- 0.16 (Successful only: 0.144 +- 0.20)
#  - Tmin/T:                             0.145 +- 0.18 (Successful only: 0.224 +- 0.22)
#
# shift = array([ 0, -8])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 185.905s:
# Simulations reached goal: 2541/10188 (7647 failures (reached horizon: 7647)) (24.94% success)
#  - Average step count:                 814.676 +- 344.64 (Successful only: 256.953 +- 248.70)
#  - Extra steps:                        765.484 +- 342.93 (Successful only: 210.492 +- 244.59)
#  - Average discounted rewards (ADR):   0.063 +- 0.16 (Successful only: 0.253 +- 0.23)
#  - Tmin/T:                             0.123 +- 0.18 (Successful only: 0.342 +- 0.25)
#
# shift = array([-2,  0])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 55.086s:
# Simulations reached goal: 10183/10188 (5 failures (reached horizon: 5)) (99.95% success)
#  - Average step count:                 230.247 +- 160.46 (Successful only: 229.869 +- 159.59)
#  - Extra steps:                        181.650 +- 159.28 (Successful only: 181.273 +- 158.41)
#  - Average discounted rewards (ADR):   0.202 +- 0.18 (Successful only: 0.202 +- 0.18)
#  - Tmin/T:                             0.305 +- 0.21 (Successful only: 0.306 +- 0.21)
#
# shift = array([-2, -2])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 67.421s:
# Simulations reached goal: 9643/10188 (545 failures (reached horizon: 545)) (94.65% success)
#  - Average step count:                 286.252 +- 245.96 (Successful only: 245.913 +- 183.03)
#  - Extra steps:                        237.615 +- 245.16 (Successful only: 197.278 +- 181.83)
#  - Average discounted rewards (ADR):   0.178 +- 0.18 (Successful only: 0.188 +- 0.18)
#  - Tmin/T:                             0.277 +- 0.20 (Successful only: 0.290 +- 0.20)
#
# shift = array([-2, -4])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 114.258s:
# Simulations reached goal: 8560/10188 (1628 failures (reached horizon: 1628)) (84.02% success)
#  - Average step count:                 494.754 +- 300.81 (Successful only: 398.663 +- 223.43)
#  - Extra steps:                        445.998 +- 300.49 (Successful only: 349.862 +- 222.60)
#  - Average discounted rewards (ADR):   0.083 +- 0.15 (Successful only: 0.099 +- 0.16)
#  - Tmin/T:                             0.171 +- 0.18 (Successful only: 0.194 +- 0.18)
#
# shift = array([-2, -6])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 172.230s:
# Simulations reached goal: 4531/10188 (5657 failures (reached horizon: 5657)) (44.47% success)
#  - Average step count:                 752.704 +- 353.33 (Successful only: 443.952 +- 330.23)
#  - Extra steps:                        703.750 +- 352.80 (Successful only: 396.446 +- 330.57)
#  - Average discounted rewards (ADR):   0.062 +- 0.14 (Successful only: 0.139 +- 0.18)
#  - Tmin/T:                             0.128 +- 0.17 (Successful only: 0.225 +- 0.22)
#
# shift = array([-2, -8])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 186.653s:
# Simulations reached goal: 2251/10188 (7937 failures (reached horizon: 7937)) (22.09% success)
#  - Average step count:                 817.938 +- 346.22 (Successful only: 175.989 +- 116.42)
#  - Extra steps:                        768.706 +- 346.12 (Successful only: 127.628 +- 114.17)
#  - Average discounted rewards (ADR):   0.058 +- 0.14 (Successful only: 0.264 +- 0.20)
#  - Tmin/T:                             0.121 +- 0.17 (Successful only: 0.373 +- 0.23)
#
# shift = array([-4,  0])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 68.103s:
# Simulations reached goal: 9777/10188 (411 failures (reached horizon: 411)) (95.97% success)
#  - Average step count:                 289.292 +- 237.34 (Successful only: 259.415 +- 191.25)
#  - Extra steps:                        240.576 +- 235.19 (Successful only: 211.036 +- 189.72)
#  - Average discounted rewards (ADR):   0.177 +- 0.18 (Successful only: 0.185 +- 0.18)
#  - Tmin/T:                             0.276 +- 0.21 (Successful only: 0.285 +- 0.21)
#
# shift = array([-4, -2])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 82.359s:
# Simulations reached goal: 9101/10188 (1087 failures (reached horizon: 1087)) (89.33% success)
#  - Average step count:                 353.040 +- 294.35 (Successful only: 275.769 +- 202.57)
#  - Extra steps:                        304.284 +- 293.44 (Successful only: 227.019 +- 200.95)
#  - Average discounted rewards (ADR):   0.153 +- 0.17 (Successful only: 0.171 +- 0.18)
#  - Tmin/T:                             0.248 +- 0.20 (Successful only: 0.272 +- 0.20)
#
# shift = array([-4, -4])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 119.595s:
# Simulations reached goal: 8768/10188 (1420 failures (reached horizon: 1420)) (86.06% success)
#  - Average step count:                 519.099 +- 291.93 (Successful only: 441.216 +- 235.62)
#  - Extra steps:                        470.225 +- 290.25 (Successful only: 392.823 +- 234.18)
#  - Average discounted rewards (ADR):   0.070 +- 0.14 (Successful only: 0.081 +- 0.15)
#  - Tmin/T:                             0.155 +- 0.16 (Successful only: 0.171 +- 0.17)
#
# shift = array([-4, -6])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 172.186s:
# Simulations reached goal: 4544/10188 (5644 failures (reached horizon: 5644)) (44.60% success)
#  - Average step count:                 753.196 +- 339.62 (Successful only: 446.647 +- 298.33)
#  - Extra steps:                        704.123 +- 339.88 (Successful only: 398.443 +- 299.62)
#  - Average discounted rewards (ADR):   0.049 +- 0.12 (Successful only: 0.111 +- 0.17)
#  - Tmin/T:                             0.117 +- 0.15 (Successful only: 0.200 +- 0.19)
#
# shift = array([-4, -8])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 175.271s:
# Simulations reached goal: 3095/10188 (7093 failures (reached horizon: 7093)) (30.38% success)
#  - Average step count:                 766.422 +- 363.09 (Successful only: 231.119 +- 149.61)
#  - Extra steps:                        717.072 +- 362.98 (Successful only: 182.193 +- 147.24)
#  - Average discounted rewards (ADR):   0.058 +- 0.13 (Successful only: 0.192 +- 0.18)
#  - Tmin/T:                             0.125 +- 0.16 (Successful only: 0.296 +- 0.21)
#
# shift = array([-6,  0])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 98.229s:
# Simulations reached goal: 7538/10188 (2650 failures (reached horizon: 2650)) (73.99% success)
#  - Average step count:                 423.534 +- 368.83 (Successful only: 220.876 +- 161.14)
#  - Extra steps:                        374.619 +- 368.95 (Successful only: 171.702 +- 159.81)
#  - Average discounted rewards (ADR):   0.154 +- 0.18 (Successful only: 0.208 +- 0.18)
#  - Tmin/T:                             0.245 +- 0.21 (Successful only: 0.314 +- 0.21)
#
# shift = array([-6, -2])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 103.946s:
# Simulations reached goal: 7292/10188 (2896 failures (reached horizon: 2896)) (71.57% success)
#  - Average step count:                 448.511 +- 371.07 (Successful only: 229.488 +- 153.68)
#  - Extra steps:                        399.557 +- 371.17 (Successful only: 180.125 +- 151.40)
#  - Average discounted rewards (ADR):   0.136 +- 0.17 (Successful only: 0.189 +- 0.18)
#  - Tmin/T:                             0.222 +- 0.20 (Successful only: 0.292 +- 0.19)
#
# shift = array([-6, -4])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 167.954s:
# Simulations reached goal: 6089/10188 (4099 failures (reached horizon: 4099)) (59.77% success)
#  - Average step count:                 734.423 +- 311.95 (Successful only: 555.642 +- 288.78)
#  - Extra steps:                        685.350 +- 312.07 (Successful only: 506.047 +- 287.68)
#  - Average discounted rewards (ADR):   0.045 +- 0.12 (Successful only: 0.076 +- 0.15)
#  - Tmin/T:                             0.113 +- 0.15 (Successful only: 0.157 +- 0.17)
#
# shift = array([-6, -6])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 190.268s:
# Simulations reached goal: 2620/10188 (7568 failures (reached horizon: 7568)) (25.72% success)
#  - Average step count:                 834.868 +- 311.75 (Successful only: 357.876 +- 267.71)
#  - Extra steps:                        785.597 +- 311.51 (Successful only: 309.869 +- 267.17)
#  - Average discounted rewards (ADR):   0.039 +- 0.12 (Successful only: 0.152 +- 0.19)
#  - Tmin/T:                             0.100 +- 0.14 (Successful only: 0.245 +- 0.22)
#
# shift = array([-6, -8])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 183.443s:
# Simulations reached goal: 2787/10188 (7401 failures (reached horizon: 7401)) (27.36% success)
#  - Average step count:                 803.280 +- 341.30 (Successful only: 280.882 +- 224.00)
#  - Extra steps:                        753.731 +- 341.28 (Successful only: 231.097 +- 220.22)
#  - Average discounted rewards (ADR):   0.051 +- 0.13 (Successful only: 0.186 +- 0.20)
#  - Tmin/T:                             0.116 +- 0.16 (Successful only: 0.292 +- 0.23)
#
# shift = array([-8,  0])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 122.392s:
# Simulations reached goal: 6198/10188 (3990 failures (reached horizon: 3990)) (60.84% success)
#  - Average step count:                 530.946 +- 402.88 (Successful only: 228.990 +- 184.39)
#  - Extra steps:                        481.754 +- 403.33 (Successful only: 179.511 +- 184.06)
#  - Average discounted rewards (ADR):   0.129 +- 0.18 (Successful only: 0.212 +- 0.19)
#  - Tmin/T:                             0.213 +- 0.21 (Successful only: 0.319 +- 0.21)
#
# shift = array([-8, -2])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 107.856s:
# Simulations reached goal: 9257/10188 (931 failures (reached horizon: 931)) (90.86% success)
#  - Average step count:                 466.100 +- 289.36 (Successful only: 412.404 +- 246.18)
#  - Extra steps:                        416.868 +- 288.10 (Successful only: 362.912 +- 243.83)
#  - Average discounted rewards (ADR):   0.092 +- 0.16 (Successful only: 0.101 +- 0.16)
#  - Tmin/T:                             0.181 +- 0.18 (Successful only: 0.194 +- 0.18)
#
# shift = array([-8, -4])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 169.529s:
# Simulations reached goal: 5116/10188 (5072 failures (reached horizon: 5072)) (50.22% success)
#  - Average step count:                 740.533 +- 337.95 (Successful only: 483.298 +- 307.48)
#  - Extra steps:                        691.183 +- 338.43 (Successful only: 435.417 +- 310.26)
#  - Average discounted rewards (ADR):   0.050 +- 0.13 (Successful only: 0.100 +- 0.16)
#  - Tmin/T:                             0.120 +- 0.15 (Successful only: 0.188 +- 0.19)
#
# shift = array([-8, -6])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 194.015s:
# Simulations reached goal: 1976/10188 (8212 failures (reached horizon: 8212)) (19.40% success)
#  - Average step count:                 850.450 +- 315.83 (Successful only: 228.942 +- 187.29)
#  - Extra steps:                        800.902 +- 315.68 (Successful only: 180.109 +- 183.63)
#  - Average discounted rewards (ADR):   0.044 +- 0.13 (Successful only: 0.228 +- 0.20)
#  - Tmin/T:                             0.103 +- 0.15 (Successful only: 0.327 +- 0.22)
#
# shift = array([-8, -8])
# Using the provided environment, not the agent environment.
# Using the provided environment, not the agent environment.
# Simulations done in 193.976s:
# Simulations reached goal: 1906/10188 (8282 failures (reached horizon: 8282)) (18.71% success)
#  - Average step count:                 850.274 +- 319.67 (Successful only: 199.680 +- 159.89)
#  - Extra steps:                        800.447 +- 318.82 (Successful only: 152.568 +- 157.64)
#  - Average discounted rewards (ADR):   0.049 +- 0.14 (Successful only: 0.263 +- 0.22)
#  - Tmin/T:                             0.110 +- 0.17 (Successful only: 0.366 +- 0.25)

# %%
# Extracting performance metrics
point_convergences = []
point_convergences_std = []
point_tmin_over_ts = []
point_tmin_over_ts_std = []

for hist in all_point_hists:
    df = hist.analysis_df
    point_convergences.append(df['converged']['mean'])
    point_convergences_std.append(df['converged']['standard_deviation'])
    point_tmin_over_ts.append(df['t_min_over_t']['success_mean'])
    point_tmin_over_ts_std.append(df['t_min_over_t']['success_standard_deviation'])

point_array_norm = (point_array * -1/2).astype(int)

point_convergences_array = np.zeros((5,5))
point_convergences_array[*point_array_norm.T] = point_convergences
point_convergences_std_array = np.zeros((5,5))
point_convergences_std_array[*point_array_norm.T] = point_convergences_std

point_tmin_over_ts_array = np.zeros((5,5))
point_tmin_over_ts_array[*point_array_norm.T] = point_tmin_over_ts
point_tmin_over_ts_std_array = np.zeros((5,5))
point_tmin_over_ts_std_array[*point_array_norm.T] = point_tmin_over_ts_std

# %%
# Convergence plot
# plt.title('Performances of the agent when shifting the source (convergence)')
plt.imshow(point_convergences_array, cmap='RdYlGn', vmax=1.0, vmin=0.0)
plt.colorbar()
plt.show()

# %%
# Convergence plot
# plt.title('Performances of the agent when shifting the source ($t_{min}/t$)')
plt.imshow(point_tmin_over_ts_array, cmap='RdYlGn', vmax=0.5, vmin=0.0)
plt.colorbar()
plt.show()
