# %%
import sys
sys.path.append('../../..')

import numpy as np

from olfactory_navigation.environment import Environment
from olfactory_navigation.agents import FSVI_Agent
from olfactory_navigation.agents.model_based_util.pomdp import Model
from olfactory_navigation.simulation import run_test
from olfactory_navigation.test_setups import run_all_starts_test

from matplotlib import pyplot as plt
from matplotlib import colors, patches
from scipy.stats import multivariate_normal
from sklearn.metrics import confusion_matrix

# %%
from model_4 import generate_model

# %%
from cupy.cuda import runtime as cuda_runtime
cuda_runtime.setDevice(2)

# %% [markdown]
# ## Variables

# %%
space_shape = np.array([101,101])
cells = np.array([7,7])

source_radius = 2
source_cell_resolution = np.array([7,7])

data_mean = [50,50]
data_covariance = 50

# %% [markdown]
# ## Model

# %%
model = generate_model(
    space_shape=space_shape,
    cells=cells,
    source_radius=source_radius,
    source_cell_resolution=source_cell_resolution,
    data_mean=data_mean,
    data_covariance=data_covariance
)

# %% [markdown]
# ## Agent

# %%
def generate_fake_data(
        space_shape: np.ndarray,
        data_mean: list,
        data_covariance,
        samples: int
        ) -> np.ndarray:
    x,y = np.meshgrid(np.arange(space_shape[0]), np.arange(space_shape[1]))
    pos = np.dstack((x, y))
    rv = multivariate_normal(data_mean, data_covariance)
    probability_map = rv.pdf(pos)

    # Normalize to have 1 at the center
    probability_map /= np.max(probability_map)

    multiple_samples = (np.random.random((samples, *space_shape)) < probability_map).astype(float)

    return multiple_samples

# %%
artificial_data = generate_fake_data(space_shape=space_shape,
                                     data_mean=data_mean,
                                     data_covariance=data_covariance,
                                     samples=1000)

artificial_env  = Environment(data_file=artificial_data,
                              data_source_position=[50, 50],
                              source_radius=source_radius,
                              shape=space_shape,
                              boundary_condition='stop',
                              start_zone='data_zone',
                              odor_present_threshold=3e-1)

artificial_env.plot()

# %%
ag = FSVI_Agent(environment=artificial_env,
                threshold=3e-8,
                space_aware=True,
                spacial_subdivisions=cells,
                model=model)

# %%
_ = ag.train(expansions=300, use_gpu=True)
# Out:
# [09/19/2024, 21:58:23] MDP_policy, not provided. Solving MDP with Value Iteration...
# [09/19/2024, 21:58:23] Sending Model to GPU...
# [09/19/2024, 21:58:24]     > Done in 0.551s
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Summary of Value Iteration run
#   - Model: 4803-state, 4-action
#   - Converged in 918 iterations and 1.3197 seconds
#   - Took on average 0.0014s per iteration
# Expansions:   0%|          | 0/300 [00:00<?, ?it/s]
# Summary of Point Based Value Iteration run
#   - Model: 4803 state, 4 action, 99 observations
#   - Converged or stopped after 300 expansion steps and 300 backup steps.
#   - Resulting value function has 1600 alpha vectors.
#   - Converged in 217.9213s
#
#   - Expand function took on average 0.0144s and yielded on average 1160.59 beliefs per iteration. (0.0001s/it/belief)
#   - Backup function took on average 0.7120s and yielded on average 5.32 alpha vectors per iteration. (0.0009s/it/alpha)
#   - Pruning function took on average 0.0000s and yielded on average prunings of 0.00 alpha vectors per iteration.

# %%
# CUSTOM PLOT
COLOR_LIST = [{
    'name': item.replace('tab:',''),
    'id': item,
    'hex': value,
    'rgb': [int(value.lstrip('#')[i:i + (len(value)-1) // 3], 16) for i in range(0, (len(value)-1), (len(value)-1) // 3)]
    } for item, value in colors.TABLEAU_COLORS.items()] # type: ignore

COLOR_ARRAY = np.array([c['rgb'] for c in COLOR_LIST])

# VF
vf = ag.value_function
new_shape = cells

# ! Select here which source to plot
source_policy = [0,0]
source_policy_id = np.arange(np.prod(cells)).reshape(cells)[*source_policy]
source_state_start = source_policy_id * np.prod(cells)

value_table = np.max(vf.alpha_vector_array, axis=0)[vf.model.state_grid[:,source_state_start:source_state_start+np.prod(cells)]].reshape(new_shape)
best_action_table = np.array(vf.actions)[np.argmax(vf.alpha_vector_array, axis=0)][vf.model.state_grid[:,source_state_start:source_state_start+np.prod(cells)]].reshape(new_shape)
best_action_colors = COLOR_ARRAY[best_action_table]

dimensions = new_shape

fig, (ax1,ax2) = plt.subplots(1,2, figsize=(5*2, 5), width_ratios=(0.55,0.45))

# Ticks
x_ticks = np.arange(0, dimensions[1], (1 if dimensions[1] < 10 else int(dimensions[1] / 10)))
y_ticks = np.arange(0, dimensions[0], (1 if dimensions[0] < 5 else int(dimensions[0] / 5)))

ax1.set_title('Value function')
ax1_plot = ax1.imshow(value_table)

if dimensions[0] >= dimensions[1]: # If higher than wide
    plt.colorbar(ax1_plot, ax=ax1)
else:
    plt.colorbar(ax1_plot, ax=ax1, location='bottom', orientation='horizontal')

ax1.set_xticks(x_ticks)
ax1.set_yticks(y_ticks)

ax2.set_title('Action policy')
ax2.imshow(best_action_colors)
p = [ patches.Patch(color=COLOR_LIST[int(i)]['id'], label=str(vf.model.action_labels[int(i)])) for i in vf.model.actions]
ax2.legend(handles=p, bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0., title='Actions')
ax2.set_xticks(x_ticks)
ax2.set_yticks(y_ticks)

plt.show()

# %% [markdown]
# ### Validation on the artificial data

# %%
hist = run_all_starts_test(ag,
                           horizon=1000,
                           use_gpu=True)
# Out:
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Simulations done in 12.133s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 214.129 +- 118.93 (Successful only: 214.129 +- 118.93)
#  - Extra steps:                        165.571 +- 112.90 (Successful only: 165.571 +- 112.90)
#  - Average discounted rewards (ADR):   0.204 +- 0.20 (Successful only: 0.204 +- 0.20)
#  - Tmin/T:                             0.292 +- 0.18 (Successful only: 0.292 +- 0.18)

# %% [markdown]
# ## Test

# %%
shift = np.array([-49,-49])

shifted_artificial_data = np.zeros(artificial_data.shape)
trimmed_artificial_data = artificial_data[:, *[slice(0, -s) if s > 0 else slice(-s, shape) for shape, s in zip(space_shape, shift)]]
shifted_artificial_data[:, *[slice(s, shape) if s >=0 else slice(0, s) for shape, s in zip(space_shape, shift)]] = trimmed_artificial_data

# %%
shifted_artificial_env  = Environment(data_file=shifted_artificial_data,
                                      data_source_position=(np.array([50,50]) + shift).tolist(),
                                      source_radius=source_radius,
                                      shape=space_shape,
                                      boundary_condition='stop',
                                      start_zone='data_zone',
                                      odor_present_threshold=3e-1)

shifted_artificial_env.plot()

# %%
hist = run_all_starts_test(ag,
                           environment=shifted_artificial_env,
                           horizon=1000,
                           use_gpu=True)
# Out:
# Using the provided environment, not the agent environment.
#   0%|          | 0/1000 [00:00<?, ?it/s]
# Simulations done in 42.536s:
# Simulations reached goal: 4781/10190 (5409 failures (reached horizon: 5409)) (46.92% success)
#  - Average step count:                 890.711 +- 182.74 (Successful only: 767.067 +- 205.87)
#  - Extra steps:                        794.567 +- 178.54 (Successful only: 676.606 +- 199.60)
#  - Average discounted rewards (ADR):   0.011 +- 0.09 (Successful only: 0.024 +- 0.14)
#  - Tmin/T:                             0.116 +- 0.07 (Successful only: 0.133 +- 0.09)

# %%
_, ax = plt.subplots(1,1, figsize=(10,10))
hist.plot_successes(ax)

# %%
_, ax = plt.subplots(1,1, figsize=(10,10))
hist.plot(2000, ax=ax)

# %%
hist.analysis_df
# Out:
#                                 y      x  optimal_steps_count converged  \
# mean                          NaN    NaN                  NaN  0.469185
# standard_deviation            NaN    NaN                  NaN   0.49905
# success_mean                  NaN    NaN                  NaN       1.0
# success_standard_deviation    NaN    NaN                  NaN       0.0
# run_0                         0.0    3.0                  1.0      True
# ...                           ...    ...                  ...       ...
# run_10185                   100.0   96.0                192.0     False
# run_10186                   100.0   97.0                193.0      True
# run_10187                   100.0   98.0                194.0     False
# run_10188                   100.0   99.0                195.0     False
# run_10189                   100.0  100.0                196.0     False
#
#                            reached_horizon  steps_taken  discounted_rewards  \
# mean                              0.530815   890.711089            0.011462
# standard_deviation                 0.49905   182.740343            0.093437
# success_mean                           0.0   767.066722            0.024380
# success_standard_deviation             0.0   205.870004            0.135267
# run_0                                False     3.000000            0.970299
# ...                                    ...          ...                 ...
# run_10185                             True  1000.000000            0.000043
# run_10186                            False   700.000000            0.000880
# run_10187                             True  1000.000000            0.000043
# run_10188                             True  1000.000000            0.000043
# run_10189                             True  1000.000000            0.000043
#
#                             extra_steps  t_min_over_t
# mean                         794.567223      0.116267
# standard_deviation           178.540788      0.071243
# success_mean                 676.605522      0.133352
# success_standard_deviation   199.604225      0.091525
# run_0                          2.000000      0.333333
# ...                                 ...           ...
# run_10185                    808.000000      0.192000
# run_10186                    507.000000      0.275714
# run_10187                    806.000000      0.194000
# run_10188                    805.000000      0.195000
# run_10189                    804.000000      0.196000
#
# [10194 rows x 9 columns]

# %% [markdown]
# ## All Tests

# %%
# Complete test
all_hists = []
for i in range(1,50,2):
    shift = np.array([-i,-i])
    print(f'\n{shift = }')

    # Setup shifted environment
    shifted_artificial_data = np.zeros(artificial_data.shape)
    trimmed_artificial_data = artificial_data[:, *[slice(0, -s) if s > 0 else slice(-s, shape) for shape, s in zip(space_shape, shift)]]
    shifted_artificial_data[:, *[slice(s, shape) if s >=0 else slice(0, s) for shape, s in zip(space_shape, shift)]] = trimmed_artificial_data

    shifted_artificial_env  = Environment(data_file=shifted_artificial_data,
                                          data_source_position=(np.array([50,50]) + shift).tolist(),
                                          source_radius=source_radius,
                                          shape=space_shape,
                                          boundary_condition='stop',
                                          start_zone='data_zone',
                                          odor_present_threshold=3e-1)

    # Running test
    hist = run_all_starts_test(ag,
                               environment=shifted_artificial_env,
                               horizon=1000,
                               use_gpu=True,
                               print_progress=False)

    all_hists.append(hist)
# Out:
# shift = array([-1, -1])
# Using the provided environment, not the agent environment.
# Simulations done in 12.425s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 221.214 +- 120.10 (Successful only: 221.214 +- 120.11)
#  - Extra steps:                        172.637 +- 114.34 (Successful only: 172.637 +- 114.34)
#  - Average discounted rewards (ADR):   0.194 +- 0.20 (Successful only: 0.194 +- 0.20)
#  - Tmin/T:                             0.283 +- 0.18 (Successful only: 0.283 +- 0.18)
#
# shift = array([-3, -3])
# Using the provided environment, not the agent environment.
# Simulations done in 29.973s:
# Simulations reached goal: 5195/10188 (4993 failures (reached horizon: 4993)) (50.99% success)
#  - Average step count:                 606.311 +- 393.89 (Successful only: 227.929 +- 110.15)
#  - Extra steps:                        557.575 +- 396.34 (Successful only: 176.357 +- 105.43)
#  - Average discounted rewards (ADR):   0.088 +- 0.16 (Successful only: 0.172 +- 0.20)
#  - Tmin/T:                             0.166 +- 0.17 (Successful only: 0.281 +- 0.18)
#
# shift = array([-5, -5])
# Using the provided environment, not the agent environment.
# Simulations done in 37.931s:
# Simulations reached goal: 2783/10188 (7405 failures (reached horizon: 7405)) (27.32% success)
#  - Average step count:                 795.075 +- 343.10 (Successful only: 249.810 +- 147.99)
#  - Extra steps:                        746.022 +- 345.02 (Successful only: 198.241 +- 147.44)
#  - Average discounted rewards (ADR):   0.043 +- 0.12 (Successful only: 0.159 +- 0.19)
#  - Tmin/T:                             0.111 +- 0.14 (Successful only: 0.277 +- 0.19)
#
# shift = array([-7, -7])
# Using the provided environment, not the agent environment.
# Simulations done in 38.061s:
# Simulations reached goal: 3359/10188 (6829 failures (reached horizon: 6829)) (32.97% success)
#  - Average step count:                 782.543 +- 335.09 (Successful only: 340.444 +- 221.32)
#  - Extra steps:                        733.014 +- 334.56 (Successful only: 291.974 +- 219.84)
#  - Average discounted rewards (ADR):   0.041 +- 0.12 (Successful only: 0.125 +- 0.18)
#  - Tmin/T:                             0.105 +- 0.13 (Successful only: 0.218 +- 0.18)
#
# shift = array([-9, -9])
# Using the provided environment, not the agent environment.
# Simulations done in 34.861s:
# Simulations reached goal: 4973/10188 (5215 failures (reached horizon: 5215)) (48.81% success)
#  - Average step count:                 708.816 +- 343.53 (Successful only: 403.463 +- 244.20)
#  - Extra steps:                        658.653 +- 344.15 (Successful only: 352.729 +- 243.54)
#  - Average discounted rewards (ADR):   0.049 +- 0.13 (Successful only: 0.101 +- 0.16)
#  - Tmin/T:                             0.121 +- 0.14 (Successful only: 0.196 +- 0.18)
#
# shift = array([-11, -11])
# Using the provided environment, not the agent environment.
# Simulations done in 34.022s:
# Simulations reached goal: 4707/10188 (5481 failures (reached horizon: 5481)) (46.20% success)
#  - Average step count:                 691.349 +- 356.05 (Successful only: 331.944 +- 185.19)
#  - Extra steps:                        640.392 +- 356.07 (Successful only: 280.445 +- 181.59)
#  - Average discounted rewards (ADR):   0.053 +- 0.13 (Successful only: 0.116 +- 0.17)
#  - Tmin/T:                             0.125 +- 0.14 (Successful only: 0.211 +- 0.16)
#
# shift = array([-13, -13])
# Using the provided environment, not the agent environment.
# Simulations done in 17.285s:
# Simulations reached goal: 10167/10188 (21 failures (reached horizon: 21)) (99.79% success)
#  - Average step count:                 311.607 +- 191.94 (Successful only: 310.185 +- 189.58)
#  - Extra steps:                        259.699 +- 191.69 (Successful only: 258.266 +- 189.28)
#  - Average discounted rewards (ADR):   0.133 +- 0.17 (Successful only: 0.133 +- 0.18)
#  - Tmin/T:                             0.238 +- 0.18 (Successful only: 0.238 +- 0.18)
#
# shift = array([-15, -15])
# Using the provided environment, not the agent environment.
# Simulations done in 13.747s:
# Simulations reached goal: 10186/10188 (2 failures (reached horizon: 2)) (99.98% success)
#  - Average step count:                 228.822 +- 141.21 (Successful only: 228.671 +- 140.82)
#  - Extra steps:                        175.804 +- 139.38 (Successful only: 175.652 +- 138.98)
#  - Average discounted rewards (ADR):   0.189 +- 0.19 (Successful only: 0.189 +- 0.19)
#  - Tmin/T:                             0.304 +- 0.20 (Successful only: 0.304 +- 0.20)
#
# shift = array([-17, -17])
# Using the provided environment, not the agent environment.
# Simulations done in 15.435s:
# Simulations reached goal: 10180/10188 (8 failures (reached horizon: 8)) (99.92% success)
#  - Average step count:                 266.318 +- 157.56 (Successful only: 265.741 +- 156.28)
#  - Extra steps:                        212.030 +- 154.28 (Successful only: 211.444 +- 152.92)
#  - Average discounted rewards (ADR):   0.150 +- 0.17 (Successful only: 0.150 +- 0.17)
#  - Tmin/T:                             0.265 +- 0.18 (Successful only: 0.265 +- 0.18)
#
# shift = array([-19, -19])
# Using the provided environment, not the agent environment.
# Simulations done in 37.667s:
# Simulations reached goal: 2962/10188 (7226 failures (reached horizon: 7226)) (29.07% success)
#  - Average step count:                 773.204 +- 361.05 (Successful only: 219.918 +- 129.53)
#  - Extra steps:                        717.488 +- 361.37 (Successful only: 164.834 +- 129.00)
#  - Average discounted rewards (ADR):   0.054 +- 0.13 (Successful only: 0.184 +- 0.18)
#  - Tmin/T:                             0.131 +- 0.16 (Successful only: 0.315 +- 0.20)
#
# shift = array([-21, -21])
# Using the provided environment, not the agent environment.
# Simulations done in 39.066s:
# Simulations reached goal: 2866/10188 (7322 failures (reached horizon: 7322)) (28.13% success)
#  - Average step count:                 804.376 +- 332.49 (Successful only: 304.600 +- 213.19)
#  - Extra steps:                        747.075 +- 332.77 (Successful only: 247.666 +- 210.82)
#  - Average discounted rewards (ADR):   0.040 +- 0.11 (Successful only: 0.142 +- 0.17)
#  - Tmin/T:                             0.117 +- 0.14 (Successful only: 0.268 +- 0.19)
#
# shift = array([-23, -23])
# Using the provided environment, not the agent environment.
# Simulations done in 38.354s:
# Simulations reached goal: 3795/10188 (6393 failures (reached horizon: 6393)) (37.25% success)
#  - Average step count:                 789.939 +- 319.95 (Successful only: 436.074 +- 274.36)
#  - Extra steps:                        730.893 +- 318.86 (Successful only: 377.506 +- 269.26)
#  - Average discounted rewards (ADR):   0.038 +- 0.11 (Successful only: 0.101 +- 0.16)
#  - Tmin/T:                             0.115 +- 0.14 (Successful only: 0.209 +- 0.19)
#
# shift = array([-25, -25])
# Using the provided environment, not the agent environment.
# Simulations done in 39.208s:
# Simulations reached goal: 2756/10188 (7432 failures (reached horizon: 7432)) (27.05% success)
#  - Average step count:                 812.318 +- 324.18 (Successful only: 306.205 +- 193.32)
#  - Extra steps:                        751.369 +- 321.61 (Successful only: 249.220 +- 184.49)
#  - Average discounted rewards (ADR):   0.037 +- 0.11 (Successful only: 0.136 +- 0.18)
#  - Tmin/T:                             0.111 +- 0.13 (Successful only: 0.241 +- 0.18)
#
# shift = array([-27, -27])
# Using the provided environment, not the agent environment.
# Simulations done in 13.441s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 235.708 +- 96.51 (Successful only: 235.708 +- 96.51)
#  - Extra steps:                        172.696 +- 92.03 (Successful only: 172.696 +- 92.03)
#  - Average discounted rewards (ADR):   0.146 +- 0.15 (Successful only: 0.146 +- 0.15)
#  - Tmin/T:                             0.300 +- 0.18 (Successful only: 0.300 +- 0.18)
#
# shift = array([-29, -29])
# Using the provided environment, not the agent environment.
# Simulations done in 10.431s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 194.615 +- 84.42 (Successful only: 194.615 +- 84.42)
#  - Extra steps:                        129.383 +- 77.24 (Successful only: 129.383 +- 77.24)
#  - Average discounted rewards (ADR):   0.194 +- 0.16 (Successful only: 0.194 +- 0.16)
#  - Tmin/T:                             0.366 +- 0.20 (Successful only: 0.366 +- 0.20)
#
# shift = array([-31, -31])
# Using the provided environment, not the agent environment.
# Simulations done in 12.381s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 218.370 +- 100.77 (Successful only: 218.370 +- 100.77)
#  - Extra steps:                        150.758 +- 94.76 (Successful only: 150.758 +- 94.76)
#  - Average discounted rewards (ADR):   0.165 +- 0.15 (Successful only: 0.165 +- 0.15)
#  - Tmin/T:                             0.344 +- 0.19 (Successful only: 0.344 +- 0.19)
#
# shift = array([-33, -33])
# Using the provided environment, not the agent environment.
# Simulations done in 39.746s:
# Simulations reached goal: 2448/10188 (7740 failures (reached horizon: 7740)) (24.03% success)
#  - Average step count:                 825.358 +- 318.26 (Successful only: 273.181 +- 142.21)
#  - Extra steps:                        755.209 +- 314.43 (Successful only: 210.528 +- 130.06)
#  - Average discounted rewards (ADR):   0.032 +- 0.10 (Successful only: 0.135 +- 0.18)
#  - Tmin/T:                             0.117 +- 0.11 (Successful only: 0.258 +- 0.14)
#
# shift = array([-35, -35])
# Using the provided environment, not the agent environment.
# Simulations done in 35.275s:
# Simulations reached goal: 4826/10188 (5362 failures (reached horizon: 5362)) (47.37% success)
#  - Average step count:                 722.280 +- 325.48 (Successful only: 413.716 +- 206.76)
#  - Extra steps:                        649.434 +- 323.86 (Successful only: 342.147 +- 201.14)
#  - Average discounted rewards (ADR):   0.033 +- 0.10 (Successful only: 0.069 +- 0.13)
#  - Tmin/T:                             0.137 +- 0.11 (Successful only: 0.207 +- 0.13)
#
# shift = array([-37, -37])
# Using the provided environment, not the agent environment.
# Simulations done in 32.117s:
# Simulations reached goal: 6073/10188 (4115 failures (reached horizon: 4115)) (59.61% success)
#  - Average step count:                 652.975 +- 322.44 (Successful only: 417.834 +- 193.73)
#  - Extra steps:                        577.274 +- 319.31 (Successful only: 343.075 +- 185.23)
#  - Average discounted rewards (ADR):   0.034 +- 0.09 (Successful only: 0.057 +- 0.11)
#  - Tmin/T:                             0.152 +- 0.12 (Successful only: 0.203 +- 0.12)
#
# shift = array([-39, -39])
# Using the provided environment, not the agent environment.
# Simulations done in 26.451s:
# Simulations reached goal: 8590/10188 (1598 failures (reached horizon: 1598)) (84.31% success)
#  - Average step count:                 524.023 +- 268.30 (Successful only: 435.477 +- 188.14)
#  - Extra steps:                        445.308 +- 268.35 (Successful only: 356.444 +- 186.62)
#  - Average discounted rewards (ADR):   0.040 +- 0.09 (Successful only: 0.047 +- 0.09)
#  - Tmin/T:                             0.189 +- 0.13 (Successful only: 0.210 +- 0.13)
#
# shift = array([-41, -41])
# Using the provided environment, not the agent environment.
# Simulations done in 25.692s:
# Simulations reached goal: 8586/10188 (1602 failures (reached horizon: 1602)) (84.28% success)
#  - Average step count:                 504.673 +- 263.58 (Successful only: 412.253 +- 167.69)
#  - Extra steps:                        422.786 +- 265.58 (Successful only: 329.099 +- 166.13)
#  - Average discounted rewards (ADR):   0.043 +- 0.09 (Successful only: 0.051 +- 0.10)
#  - Tmin/T:                             0.206 +- 0.14 (Successful only: 0.230 +- 0.14)
#
# shift = array([-43, -43])
# Using the provided environment, not the agent environment.
# Simulations done in 33.254s:
# Simulations reached goal: 5549/10188 (4639 failures (reached horizon: 4639)) (54.47% success)
#  - Average step count:                 677.956 +- 311.92 (Successful only: 408.726 +- 139.44)
#  - Extra steps:                        592.738 +- 315.90 (Successful only: 320.748 +- 139.01)
#  - Average discounted rewards (ADR):   0.025 +- 0.08 (Successful only: 0.045 +- 0.10)
#  - Tmin/T:                             0.170 +- 0.13 (Successful only: 0.243 +- 0.14)
#
# shift = array([-45, -45])
# Using the provided environment, not the agent environment.
# Simulations done in 40.561s:
# Simulations reached goal: 2927/10188 (7261 failures (reached horizon: 7261)) (28.73% success)
#  - Average step count:                 843.179 +- 264.75 (Successful only: 454.152 +- 177.84)
#  - Extra steps:                        754.471 +- 268.19 (Successful only: 361.771 +- 173.15)
#  - Average discounted rewards (ADR):   0.014 +- 0.08 (Successful only: 0.049 +- 0.14)
#  - Tmin/T:                             0.130 +- 0.11 (Successful only: 0.237 +- 0.14)
#
# shift = array([-47, -47])
# Using the provided environment, not the agent environment.
# Simulations done in 33.732s:
# Simulations reached goal: 8661/10188 (1527 failures (reached horizon: 1527)) (85.01% success)
#  - Average step count:                 688.767 +- 233.23 (Successful only: 633.894 +- 209.53)
#  - Extra steps:                        596.411 +- 229.84 (Successful only: 542.308 +- 205.76)
#  - Average discounted rewards (ADR):   0.020 +- 0.10 (Successful only: 0.024 +- 0.11)
#  - Tmin/T:                             0.153 +- 0.10 (Successful only: 0.163 +- 0.10)
#
# shift = array([-49, -49])
# Using the provided environment, not the agent environment.
# Simulations done in 42.595s:
# Simulations reached goal: 4781/10190 (5409 failures (reached horizon: 5409)) (46.92% success)
#  - Average step count:                 890.711 +- 182.74 (Successful only: 767.067 +- 205.87)
#  - Extra steps:                        794.567 +- 178.54 (Successful only: 676.606 +- 199.60)
#  - Average discounted rewards (ADR):   0.011 +- 0.09 (Successful only: 0.024 +- 0.14)
#  - Tmin/T:                             0.116 +- 0.07 (Successful only: 0.133 +- 0.09)

# %%
# Extracting performance metrics
convergences = []
convergences_std = []
tmin_over_ts = []
tmin_over_ts_std = []

for hist in all_hists:
    df = hist.analysis_df
    convergences.append(df['converged']['mean'])
    convergences_std.append(df['converged']['standard_deviation'])
    tmin_over_ts.append(df['t_min_over_t']['success_mean'])
    tmin_over_ts_std.append(df['t_min_over_t']['success_standard_deviation'])

# %%
_, (ax0) = plt.subplots(1,1, figsize=(10,5), gridspec_kw={'hspace':0.3})
xs = (np.arange(len(convergences)) * 2) + 1

# Convergence plot
ax0.set_title('Performances of the agent when shifting the source (convergence)')
ax0.errorbar(xs, convergences, convergences_std)

# Other formatting
ax0.grid()
ax0.set_xticks(xs)
ax0.set_yticks([0.0, 0.5, 1.0], labels=[0, 50, 100])
ax0.set_ylabel('Convergence (%)')
ax0.set_xlabel('Shift from center along diagonal')
# Out:
# Text(0.5, 0, 'Shift from center along diagonal')

# %%
_, (ax1) = plt.subplots(1,1, figsize=(10,5), gridspec_kw={'hspace':0.3})

# tmin over t plot
ax1.set_title('Performances of the agent when shifting the source ($t_{min}/t$)')
ax1.errorbar(xs, tmin_over_ts, tmin_over_ts_std)

# Other formatting
ax1.grid()
ax1.set_xticks(xs)
ax1.set_yticks(np.arange(6)/10)
ax1.set_ylabel('$t_{min}/t$')
ax1.set_xlabel('Shift from center along diagonal')

# %% [markdown]
# ## Grid check

# %%
point_array = np.array(list(np.ndindex(5,5))) * -2

print(f'{len(point_array) = }')
# Out:
# len(point_array) = 25

# %%
# Complete test
all_point_hists = []
for shift in point_array:
    print(f'\n{shift = }')

    # Setup shifted environment
    shifted_artificial_data = np.zeros(artificial_data.shape)
    trimmed_artificial_data = artificial_data[:, *[slice(0, -s) if s > 0 else slice(-s, shape) for shape, s in zip(space_shape, shift)]]
    shifted_artificial_data[:, *[slice(s, shape) if s >=0 else slice(0, s) for shape, s in zip(space_shape, shift)]] = trimmed_artificial_data

    shifted_artificial_env  = Environment(data_file=shifted_artificial_data,
                                          data_source_position=(np.array([50,50]) + shift).tolist(),
                                          source_radius=source_radius,
                                          shape=space_shape,
                                          boundary_condition='stop',
                                          start_zone='data_zone',
                                          odor_present_threshold=3e-1)

    # Running test
    hist = run_all_starts_test(ag,
                               environment=shifted_artificial_env,
                               horizon=1000,
                               use_gpu=True,
                               print_progress=False)

    all_point_hists.append(hist)
# Out:
# shift = array([0, 0])
# Using the provided environment, not the agent environment.
# Simulations done in 12.088s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 214.129 +- 118.93 (Successful only: 214.129 +- 118.93)
#  - Extra steps:                        165.571 +- 112.90 (Successful only: 165.571 +- 112.90)
#  - Average discounted rewards (ADR):   0.204 +- 0.20 (Successful only: 0.204 +- 0.20)
#  - Tmin/T:                             0.292 +- 0.18 (Successful only: 0.292 +- 0.18)
#
# shift = array([ 0, -2])
# Using the provided environment, not the agent environment.
# Simulations done in 12.304s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 219.954 +- 117.25 (Successful only: 219.954 +- 117.26)
#  - Extra steps:                        171.357 +- 111.60 (Successful only: 171.357 +- 111.60)
#  - Average discounted rewards (ADR):   0.191 +- 0.19 (Successful only: 0.191 +- 0.19)
#  - Tmin/T:                             0.278 +- 0.17 (Successful only: 0.278 +- 0.17)
#
# shift = array([ 0, -4])
# Using the provided environment, not the agent environment.
# Simulations done in 20.036s:
# Simulations reached goal: 9573/10188 (615 failures (reached horizon: 615)) (93.96% success)
#  - Average step count:                 376.631 +- 222.24 (Successful only: 336.584 +- 161.24)
#  - Extra steps:                        327.915 +- 219.10 (Successful only: 287.875 +- 156.51)
#  - Average discounted rewards (ADR):   0.097 +- 0.16 (Successful only: 0.103 +- 0.16)
#  - Tmin/T:                             0.183 +- 0.15 (Successful only: 0.192 +- 0.15)
#
# shift = array([ 0, -6])
# Using the provided environment, not the agent environment.
# Simulations done in 34.412s:
# Simulations reached goal: 4464/10188 (5724 failures (reached horizon: 5724)) (43.82% success)
#  - Average step count:                 705.422 +- 359.31 (Successful only: 327.697 +- 201.78)
#  - Extra steps:                        656.508 +- 358.58 (Successful only: 278.789 +- 197.60)
#  - Average discounted rewards (ADR):   0.062 +- 0.15 (Successful only: 0.141 +- 0.20)
#  - Tmin/T:                             0.125 +- 0.15 (Successful only: 0.223 +- 0.18)
#
# shift = array([ 0, -8])
# Using the provided environment, not the agent environment.
# Simulations done in 20.580s:
# Simulations reached goal: 9866/10188 (322 failures (reached horizon: 322)) (96.84% success)
#  - Average step count:                 394.429 +- 233.38 (Successful only: 374.665 +- 209.50)
#  - Extra steps:                        345.237 +- 229.97 (Successful only: 325.576 +- 205.86)
#  - Average discounted rewards (ADR):   0.097 +- 0.16 (Successful only: 0.101 +- 0.16)
#  - Tmin/T:                             0.182 +- 0.16 (Successful only: 0.186 +- 0.16)
#
# shift = array([-2,  0])
# Using the provided environment, not the agent environment.
# Simulations done in 12.613s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 229.455 +- 125.45 (Successful only: 229.455 +- 125.46)
#  - Extra steps:                        180.857 +- 119.12 (Successful only: 180.857 +- 119.13)
#  - Average discounted rewards (ADR):   0.188 +- 0.20 (Successful only: 0.188 +- 0.20)
#  - Tmin/T:                             0.277 +- 0.18 (Successful only: 0.277 +- 0.18)
#
# shift = array([-2, -2])
# Using the provided environment, not the agent environment.
# Simulations done in 13.139s:
# Simulations reached goal: 10188/10188 (0 failures (reached horizon: 0)) (100.00% success)
#  - Average step count:                 236.113 +- 122.95 (Successful only: 236.113 +- 122.95)
#  - Extra steps:                        187.476 +- 117.83 (Successful only: 187.476 +- 117.83)
#  - Average discounted rewards (ADR):   0.171 +- 0.19 (Successful only: 0.171 +- 0.19)
#  - Tmin/T:                             0.261 +- 0.17 (Successful only: 0.261 +- 0.17)
#
# shift = array([-2, -4])
# Using the provided environment, not the agent environment.
# Simulations done in 36.010s:
# Simulations reached goal: 3284/10188 (6904 failures (reached horizon: 6904)) (32.23% success)
#  - Average step count:                 751.022 +- 368.10 (Successful only: 227.592 +- 126.76)
#  - Extra steps:                        702.266 +- 368.38 (Successful only: 178.103 +- 121.28)
#  - Average discounted rewards (ADR):   0.062 +- 0.15 (Successful only: 0.193 +- 0.22)
#  - Tmin/T:                             0.126 +- 0.16 (Successful only: 0.290 +- 0.20)
#
# shift = array([-2, -6])
# Using the provided environment, not the agent environment.
# Simulations done in 36.120s:
# Simulations reached goal: 4189/10188 (5999 failures (reached horizon: 5999)) (41.12% success)
#  - Average step count:                 750.694 +- 340.29 (Successful only: 393.666 +- 255.27)
#  - Extra steps:                        701.739 +- 342.05 (Successful only: 342.776 +- 255.29)
#  - Average discounted rewards (ADR):   0.047 +- 0.13 (Successful only: 0.115 +- 0.19)
#  - Tmin/T:                             0.115 +- 0.15 (Successful only: 0.211 +- 0.19)
#
# shift = array([-2, -8])
# Using the provided environment, not the agent environment.
# Simulations done in 23.844s:
# Simulations reached goal: 9818/10188 (370 failures (reached horizon: 370)) (96.37% success)
#  - Average step count:                 468.535 +- 238.28 (Successful only: 448.507 +- 218.81)
#  - Extra steps:                        419.304 +- 234.60 (Successful only: 399.512 +- 215.21)
#  - Average discounted rewards (ADR):   0.065 +- 0.14 (Successful only: 0.068 +- 0.14)
#  - Tmin/T:                             0.148 +- 0.14 (Successful only: 0.152 +- 0.14)
#
# shift = array([-4,  0])
# Using the provided environment, not the agent environment.
# Simulations done in 18.415s:
# Simulations reached goal: 9602/10188 (586 failures (reached horizon: 586)) (94.25% success)
#  - Average step count:                 346.840 +- 245.83 (Successful only: 306.979 +- 191.05)
#  - Extra steps:                        298.124 +- 247.40 (Successful only: 257.747 +- 191.24)
#  - Average discounted rewards (ADR):   0.129 +- 0.18 (Successful only: 0.137 +- 0.18)
#  - Tmin/T:                             0.228 +- 0.19 (Successful only: 0.239 +- 0.19)
#
# shift = array([-4, -2])
# Using the provided environment, not the agent environment.
# Simulations done in 24.963s:
# Simulations reached goal: 6608/10188 (3580 failures (reached horizon: 3580)) (64.86% success)
#  - Average step count:                 498.781 +- 380.58 (Successful only: 227.236 +- 116.05)
#  - Extra steps:                        450.025 +- 383.51 (Successful only: 175.951 +- 112.89)
#  - Average discounted rewards (ADR):   0.113 +- 0.17 (Successful only: 0.174 +- 0.19)
#  - Tmin/T:                             0.201 +- 0.18 (Successful only: 0.286 +- 0.18)
#
# shift = array([-4, -4])
# Using the provided environment, not the agent environment.
# Simulations done in 40.681s:
# Simulations reached goal: 2030/10188 (8158 failures (reached horizon: 8158)) (19.93% success)
#  - Average step count:                 860.370 +- 297.58 (Successful only: 299.236 +- 226.37)
#  - Extra steps:                        811.495 +- 297.90 (Successful only: 249.988 +- 223.57)
#  - Average discounted rewards (ADR):   0.036 +- 0.13 (Successful only: 0.179 +- 0.24)
#  - Tmin/T:                             0.094 +- 0.14 (Successful only: 0.275 +- 0.23)
#
# shift = array([-4, -6])
# Using the provided environment, not the agent environment.
# Simulations done in 40.478s:
# Simulations reached goal: 2296/10188 (7892 failures (reached horizon: 7892)) (22.54% success)
#  - Average step count:                 850.668 +- 299.34 (Successful only: 337.373 +- 239.79)
#  - Extra steps:                        801.595 +- 301.08 (Successful only: 285.513 +- 238.70)
#  - Average discounted rewards (ADR):   0.034 +- 0.12 (Successful only: 0.153 +- 0.21)
#  - Tmin/T:                             0.095 +- 0.14 (Successful only: 0.258 +- 0.22)
#
# shift = array([-4, -8])
# Using the provided environment, not the agent environment.
# Simulations done in 40.204s:
# Simulations reached goal: 2250/10188 (7938 failures (reached horizon: 7938)) (22.08% success)
#  - Average step count:                 836.181 +- 315.40 (Successful only: 258.228 +- 147.46)
#  - Extra steps:                        786.830 +- 316.03 (Successful only: 207.679 +- 141.79)
#  - Average discounted rewards (ADR):   0.036 +- 0.12 (Successful only: 0.164 +- 0.21)
#  - Tmin/T:                             0.098 +- 0.13 (Successful only: 0.270 +- 0.21)
#
# shift = array([-6,  0])
# Using the provided environment, not the agent environment.
# Simulations done in 26.553s:
# Simulations reached goal: 6400/10188 (3788 failures (reached horizon: 3788)) (62.82% success)
#  - Average step count:                 527.900 +- 383.11 (Successful only: 248.475 +- 153.78)
#  - Extra steps:                        478.985 +- 382.83 (Successful only: 199.328 +- 150.59)
#  - Average discounted rewards (ADR):   0.109 +- 0.17 (Successful only: 0.173 +- 0.19)
#  - Tmin/T:                             0.189 +- 0.19 (Successful only: 0.273 +- 0.19)
#
# shift = array([-6, -2])
# Using the provided environment, not the agent environment.
# Simulations done in 27.622s:
# Simulations reached goal: 6451/10188 (3737 failures (reached horizon: 3737)) (63.32% success)
#  - Average step count:                 554.775 +- 373.75 (Successful only: 296.860 +- 198.16)
#  - Extra steps:                        505.821 +- 374.32 (Successful only: 247.133 +- 196.41)
#  - Average discounted rewards (ADR):   0.091 +- 0.16 (Successful only: 0.144 +- 0.18)
#  - Tmin/T:                             0.172 +- 0.17 (Successful only: 0.244 +- 0.18)
#
# shift = array([-6, -4])
# Using the provided environment, not the agent environment.
# Simulations done in 35.042s:
# Simulations reached goal: 4049/10188 (6139 failures (reached horizon: 6139)) (39.74% success)
#  - Average step count:                 720.953 +- 365.66 (Successful only: 297.869 +- 198.45)
#  - Extra steps:                        671.880 +- 366.76 (Successful only: 248.002 +- 198.98)
#  - Average discounted rewards (ADR):   0.056 +- 0.14 (Successful only: 0.141 +- 0.18)
#  - Tmin/T:                             0.127 +- 0.15 (Successful only: 0.246 +- 0.18)
#
# shift = array([-6, -6])
# Using the provided environment, not the agent environment.
# Simulations done in 37.695s:
# Simulations reached goal: 3098/10188 (7090 failures (reached horizon: 7090)) (30.41% success)
#  - Average step count:                 783.625 +- 342.72 (Successful only: 288.435 +- 184.19)
#  - Extra steps:                        734.354 +- 343.31 (Successful only: 238.875 +- 183.73)
#  - Average discounted rewards (ADR):   0.044 +- 0.12 (Successful only: 0.144 +- 0.19)
#  - Tmin/T:                             0.110 +- 0.14 (Successful only: 0.248 +- 0.19)
#
# shift = array([-6, -8])
# Using the provided environment, not the agent environment.
# Simulations done in 38.360s:
# Simulations reached goal: 2960/10188 (7228 failures (reached horizon: 7228)) (29.05% success)
#  - Average step count:                 796.583 +- 334.29 (Successful only: 299.862 +- 192.00)
#  - Extra steps:                        747.035 +- 334.24 (Successful only: 250.146 +- 188.11)
#  - Average discounted rewards (ADR):   0.042 +- 0.12 (Successful only: 0.145 +- 0.19)
#  - Tmin/T:                             0.106 +- 0.14 (Successful only: 0.243 +- 0.19)
#
# shift = array([-8,  0])
# Using the provided environment, not the agent environment.
# Simulations done in 17.921s:
# Simulations reached goal: 9919/10188 (269 failures (reached horizon: 269)) (97.36% success)
#  - Average step count:                 332.930 +- 228.12 (Successful only: 314.840 +- 202.63)
#  - Extra steps:                        283.738 +- 226.17 (Successful only: 265.662 +- 200.40)
#  - Average discounted rewards (ADR):   0.131 +- 0.17 (Successful only: 0.134 +- 0.17)
#  - Tmin/T:                             0.221 +- 0.17 (Successful only: 0.225 +- 0.17)
#
# shift = array([-8, -2])
# Using the provided environment, not the agent environment.
# Simulations done in 17.407s:
# Simulations reached goal: 10131/10188 (57 failures (reached horizon: 57)) (99.44% success)
#  - Average step count:                 317.697 +- 186.12 (Successful only: 313.858 +- 179.45)
#  - Extra steps:                        268.465 +- 183.95 (Successful only: 264.626 +- 177.18)
#  - Average discounted rewards (ADR):   0.123 +- 0.17 (Successful only: 0.123 +- 0.17)
#  - Tmin/T:                             0.216 +- 0.16 (Successful only: 0.217 +- 0.16)
#
# shift = array([-8, -4])
# Using the provided environment, not the agent environment.
# Simulations done in 36.439s:
# Simulations reached goal: 3467/10188 (6721 failures (reached horizon: 6721)) (34.03% success)
#  - Average step count:                 751.678 +- 358.13 (Successful only: 270.291 +- 160.06)
#  - Extra steps:                        702.328 +- 359.54 (Successful only: 219.005 +- 157.70)
#  - Average discounted rewards (ADR):   0.050 +- 0.13 (Successful only: 0.148 +- 0.18)
#  - Tmin/T:                             0.120 +- 0.15 (Successful only: 0.258 +- 0.18)
#
# shift = array([-8, -6])
# Using the provided environment, not the agent environment.
# Simulations done in 37.953s:
# Simulations reached goal: 3289/10188 (6899 failures (reached horizon: 6899)) (32.28% success)
#  - Average step count:                 784.945 +- 336.45 (Successful only: 333.845 +- 223.97)
#  - Extra steps:                        735.396 +- 336.16 (Successful only: 285.109 +- 222.78)
#  - Average discounted rewards (ADR):   0.042 +- 0.12 (Successful only: 0.129 +- 0.18)
#  - Tmin/T:                             0.106 +- 0.13 (Successful only: 0.225 +- 0.19)
#
# shift = array([-8, -8])
# Using the provided environment, not the agent environment.
# Simulations done in 35.692s:
# Simulations reached goal: 4437/10188 (5751 failures (reached horizon: 5751)) (43.55% success)
#  - Average step count:                 737.386 +- 341.11 (Successful only: 397.001 +- 248.87)
#  - Extra steps:                        687.560 +- 340.40 (Successful only: 347.842 +- 247.00)
#  - Average discounted rewards (ADR):   0.046 +- 0.12 (Successful only: 0.105 +- 0.17)
#  - Tmin/T:                             0.113 +- 0.14 (Successful only: 0.194 +- 0.17)

# %%
# Extracting performance metrics
point_convergences = []
point_convergences_std = []
point_tmin_over_ts = []
point_tmin_over_ts_std = []

for hist in all_point_hists:
    df = hist.analysis_df
    point_convergences.append(df['converged']['mean'])
    point_convergences_std.append(df['converged']['standard_deviation'])
    point_tmin_over_ts.append(df['t_min_over_t']['success_mean'])
    point_tmin_over_ts_std.append(df['t_min_over_t']['success_standard_deviation'])

point_array_norm = (point_array * -1/2).astype(int)

point_convergences_array = np.zeros((5,5))
point_convergences_array[*point_array_norm.T] = point_convergences
point_convergences_std_array = np.zeros((5,5))
point_convergences_std_array[*point_array_norm.T] = point_convergences_std

point_tmin_over_ts_array = np.zeros((5,5))
point_tmin_over_ts_array[*point_array_norm.T] = point_tmin_over_ts
point_tmin_over_ts_std_array = np.zeros((5,5))
point_tmin_over_ts_std_array[*point_array_norm.T] = point_tmin_over_ts_std

# %%
# Convergence plot
# plt.title('Performances of the agent when shifting the source (convergence)')
plt.imshow(point_convergences_array, cmap='RdYlGn', vmax=1.0, vmin=0.0)
plt.colorbar()
plt.show()

# %%
# Convergence plot
# plt.title('Performances of the agent when shifting the source ($t_{min}/t$)')
plt.imshow(point_tmin_over_ts_array, cmap='RdYlGn', vmax=0.5, vmin=0.0)
plt.colorbar()
plt.show()
